# %% [markdown]
# # Tutorial 2 - The Queens & The Art of Branching

# %% [markdown]
# **Important:** You must fully complete Tutorial $i-1$ before starting Tutorial $i$ ($i>1$).
#
# Constraint programming is used to solve highly combinatorial and complex problems.
# In order to master CP, you need to get used to the philosophy behind this approach as well as the different
# techniques used along with it. We will guide you in this process step by step in the upcoming tutorials. We will be using "toy" puzzles/problems only for the purpose of learning different faces of CP. In real life problems, things get messed up easily and require decision and policy makes to agree opon the problem at hand.. (Trust us, we've been there..)
#
# In this tutorial, we use the N-Queens problem, one of oldest and classical problems solved efficiently by CP, as a case study.

# %% [markdown]
# ## 1. The N-Queens problem

# %% [markdown]
# You are given an N-by-N chessboard, and your goal is to place N chess queens on it so that no two queens threaten each other:
#
# <div class="row" style="margin-top: 10px">
#     <div class="col-md-5">
#         <img src="display/images/empty-chessboard.png" style="margin-right: 0; width: 160px;" />
#     </div>
#     <div class="col-md-2" style="display: table">
#         <i class="fa fa-arrow-right" style="display: table-cell; font-size: 50px;
#         margin: auto; text-align: center; vertical-align: middle; height: 150px"></i>
#     </div>
#     <div class="col-md-5">
#         <img src="display/images/nqueens8-chessboard.png" style="margin-left: 0; width: 160px;" />
#     </div>
# </div>
#
# Formally, a solution to the N-queens problem requires that no two queens share the same row, column or diagnoal.

# %% [markdown]
# ### 1.1. Model without global constraints

# %% [markdown]
# **Exercice**: Create a function `decomposition_model(N)` that models the problem using only binary inequality constrants (no global constraint) and returns an instance of `CpoModel` for the n-queens problem with `N` queens.

# %%
from config import setup
setup()

# %%
from docplex.cp.model import *
from docplex.cp.config import get_default


def decomposition_model(N):
    mdl=CpoModel()
    L=mdl.integer_var_list(N,0,N-1,'L')
    mdl.add(all_diff(L))
    for i in range (N):
        for j in range (i+1,N) : 
            mdl.add(abs(i-j)!=abs(L[i]-L[j]))
    return mdl

# %% [markdown]
# **Exercice:** Test your function by solving the n-queens problem for small values of $N$ ($N < 20$).
#
# <div class="alert alert-block alert-info">
#
# Use the `display.n_queens` function in order to display a solution for the n-queens problem. This function can take a list of `int` corresponding to the column of the queens in order to display them.
#
# </div>

# %%
N=8
mdl=decomposition_model(N)
sol=mdl.solve()


allvars = sol.get_all_var_solutions()

#lvars = [v.get_value() for v in allvars]
#print(lvars)

display.n_queens(allvars)
# %matplotlib inline

#print(lvars)

#mdl.export_model()
# Out:
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 8 variables, 29 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 24.0 (before), 24.0 (after)
#  !  . Memory usage      : 299.2 kB (before), 299.2 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     52  0.01s                  4  = L_0
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 52
#  ! Number of fails        : 22
#  ! Total memory usage     : 720.1 kB (680.0 kB CP Optimizer + 40.0 kB Concert)
#  ! Time spent in solve    : 0.01s (0.01s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 5200.0
#  ! ----------------------------------------------------------------------------

# %% [markdown]
# **Question**: How many solutions are there for $N = 3,~\ldots,~10$?
#
# **Note:** To answer this question, you must force the solver to use a depth first strategy using  `CpoModel.start_search(SearchType="DepthFirst")`.

# %%
def count_iterable(i):
    return sum(1 for e in i)

# %%
for N in range(3,11):
    mdl=decomposition_model(N)
    lsols = mdl.start_search(SearchType="DepthFirst")
    print("         **** THE NUMBER OF SOLUTIONS FOR N =",N,"IS",count_iterable(lsols),"****")
# Out:
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 3 variables, 4 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 4.8 (before), 4.8 (after)
#  !  . Memory usage      : 266.9 kB (before), 266.9 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  ! ----------------------------------------------------------------------------
#  ! Search completed, model has no solution.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 4
#  ! Number of fails        : 3
#  ! Total memory usage     : 534.6 kB (494.9 kB CP Optimizer + 39.6 kB Concert)
#  ! Time spent in solve    : 0.01s (0.00s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 400.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 3 IS 0 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 4 variables, 7 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 8.0 (before), 8.0 (after)
#  !  . Memory usage      : 267.0 kB (before), 267.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      3  0.01s                  2 != L_2
#  *                     17  0.01s                  0  = L_2
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 2 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 18
#  ! Number of fails        : 8
#  ! Total memory usage     : 571.5 kB (531.8 kB CP Optimizer + 39.7 kB Concert)
#  ! Time spent in solve    : 0.01s (0.00s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 1800.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 4 IS 2 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 5 variables, 11 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 11.6 (before), 11.6 (after)
#  !  . Memory usage      : 267.0 kB (before), 267.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      2  0.01s                  2  = L_2
#  *                      5  0.01s                  2  = L_4
#  *                     10  0.01s                  0  = L_0
#  *                     14  0.01s                  0 != L_4
#  *                     21  0.01s                  0  = L_4
#  *                     25  0.01s                  1 != L_4
#  *                     33  0.01s                  0  = L_4
#  *                     35  0.01s                  2 != L_0
#  *                     41  0.01s                  0 != L_4
#  *                     42  0.01s                  1 != L_2
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 10 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 42
#  ! Number of fails        : 12
#  ! Total memory usage     : 576.2 kB (536.4 kB CP Optimizer + 39.8 kB Concert)
#  ! Time spent in solve    : 0.01s (0.00s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 4200.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 5 IS 10 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 6 variables, 16 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 15.5 (before), 15.5 (after)
#  !  . Memory usage      : 267.1 kB (before), 267.1 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     32  0.01s                  0 != L_3
#  *                     70  0.01s                  1  = L_3
#  *                     83  0.01s                  0  = L_4
#  *                    122  0.01s                  0  = L_3
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 4 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 146
#  ! Number of fails        : 70
#  ! Total memory usage     : 593.9 kB (554.0 kB CP Optimizer + 39.9 kB Concert)
#  ! Time spent in solve    : 0.01s (0.00s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 14600.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 6 IS 4 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 7 variables, 22 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.00s extraction + 0.01s propagation)
#  !  . Log search space  : 19.7 (before), 19.7 (after)
#  !  . Memory usage      : 299.2 kB (before), 299.2 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      7  0.01s                  3 != L_1
#  *                     15  0.01s                  3 != L_4
#  *                     22  0.01s                  1  = L_2
#  *                     27  0.01s                  1  = L_3
#  *                     43  0.01s                  5 != L_3
#  *                     47  0.01s                  1 != L_1
#  *                     56  0.01s                  1 != L_0
#  *                     71  0.01s                  3 != L_4
#  *                     82  0.01s                  0  = L_3
#  *                    111  0.01s                  0 != L_3
#  *                    131  0.01s                  0 != L_4
#  *                    149  0.01s                  1  = L_3
#  *                    163  0.01s                  0  = L_4
#  *                    177  0.01s                  0  = L_2
#  *                    184  0.01s                  0  = L_6
#  *                    213  0.01s                  0  = L_2
#  *                    214  0.01s                  0 != L_2
#  *                    248  0.01s                  0  = L_4
#  *                    267  0.01s                  0  = L_3
#  *                    277  0.01s                  0 != L_4
#  ! Time = 0.01s, Average fail depth = 4, Memory usage = 559.6 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    286  0.01s                  0 != L_3
#  *                    300  0.01s                  0  = L_0
#  *                    330  0.01s                  2 != L_4
#  *                    352  0.01s                  1 != L_0
#  *                    369  0.01s                  1 != L_0
#  *                    386  0.01s                  0  = L_3
#  *                    394  0.01s                  0 != L_2
#  *                    407  0.01s                  1  = L_3
#  *                    431  0.01s                  1 != L_3
#  *                    447  0.01s                  0  = L_4
#  *                    470  0.01s                  1 != L_2
#  *                    512  0.01s                  0  = L_1
#  *                    527  0.01s                  1  = L_4
#  *                    542  0.01s                  0 != L_3
#  *                    544  0.01s                  3  = L_0
#  *                    550  0.01s                  0  = L_1
#  *                    561  0.01s                  1 != L_3
#  *                    567  0.01s                  0  = L_3
#  *                    583  0.01s                  0 != L_2
#  *                    587  0.01s                  0 != L_6
#  ! Time = 0.01s, Average fail depth = 4, Memory usage = 559.6 kB
#  !               Branches  Non-fixed            Branch decision
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 40 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 590
#  ! Number of fails        : 256
#  ! Total memory usage     : 600.3 kB (560.4 kB CP Optimizer + 40.0 kB Concert)
#  ! Time spent in solve    : 0.01s (0.01s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 59000.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 7 IS 40 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 8 variables, 29 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 24.0 (before), 24.0 (after)
#  !  . Memory usage      : 299.2 kB (before), 299.2 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      4  0.01s                  1  = L_2
#  *                     37  0.01s                  1  = L_0
#  *                     56  0.01s                  1  = L_2
#  *                     94  0.01s                  1 != L_2
#  *                    112  0.01s                  2  = L_1
#  *                    119  0.01s                  1 != L_3
#  *                    137  0.01s                  3 != L_3
#  *                    158  0.01s                  1  = L_1
#  *                    163  0.01s                  4  = L_7
#  *                    171  0.01s                  1  = L_3
#  *                    194  0.01s                  4 != L_7
#  *                    201  0.01s                  1 != L_7
#  *                    219  0.01s                  2 != L_2
#  *                    230  0.01s                  1  = L_2
#  *                    247  0.01s                  3 != L_6
#  *                    249  0.01s                  2  = L_6
#  *                    287  0.01s                  4  = L_4
#  *                    289  0.01s                  4  = L_3
#  *                    296  0.01s                  3  = L_1
#  *                    311  0.01s                  0  = L_0
#  ! Time = 0.01s, Average fail depth = 5, Memory usage = 561.0 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    319  0.01s                  0  = L_3
#  *                    322  0.01s                  4  = L_0
#  *                    347  0.01s                  0 != L_4
#  *                    358  0.01s                  3  = L_0
#  *                    359  0.01s                  3 != L_0
#  *                    416  0.01s                  3  = L_4
#  *                    457  0.01s                  4 != L_6
#  *                    459  0.01s                  0  = L_1
#  *                    479  0.01s                  4  = L_0
#  *                    481  0.01s                  5 != L_3
#  *                    687  0.01s                  1 != L_6
#  *                    718  0.01s                  1 != L_3
#  *                    772  0.01s                  0  = L_6
#  *                    794  0.01s                  0 != L_4
#  *                    885  0.01s                  1 != L_3
#  *                    941  0.01s                  0  = L_3
#  *                    947  0.01s                  0  = L_4
#                      1000          2              0  = L_0
#  *                   1012  0.01s                  6  = L_7
#  *                   1013  0.01s                  6 != L_7
#  ! Time = 0.01s, Average fail depth = 5, Memory usage = 561.3 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1111  0.01s                  1 != L_3
#  *                   1145  0.01s                  6  = L_4
#  *                   1169  0.01s                  0  = L_4
#  *                   1189  0.01s                  2 != L_7
#  *                   1206  0.01s                  0  = L_4
#  *                   1209  0.01s                  0  = L_0
#  *                   1223  0.01s                  1  = L_2
#  *                   1242  0.01s                  5 != L_2
#  *                   1251  0.01s                  6  = L_4
#  *                   1252  0.01s                  6 != L_4
#  *                   1268  0.01s                  3  = L_7
#  *                   1291  0.01s                  0  = L_2
#  *                   1312  0.01s                  0 != L_4
#  *                   1334  0.01s                  1 != L_0
#  *                   1419  0.01s                  1 != L_4
#  *                   1425  0.01s                  3 != L_4
#  *                   1484  0.01s                  1  = L_0
#  *                   1494  0.01s                  0  = L_6
#  *                   1545  0.01s                  0 != L_6
#  *                   1637  0.01s                  0  = L_4
#  ! Time = 0.01s, Average fail depth = 5, Memory usage = 561.3 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1657  0.01s                  4 != L_6
#  *                   1697  0.01s                  6 != L_1
#  *                   1720  0.01s                  3  = L_6
#  *                   1826  0.01s                  3  = L_0
#  *                   1857  0.01s                  1  = L_6
#  *                   1858  0.01s                  1 != L_6
#  *                   1914  0.01s                  0  = L_4
#  *                   1919  0.01s                  0  = L_3
#  *                   1952  0.01s                  0 != L_3
#  *                   1986  0.01s                  1  = L_6
#  *                   1992  0.01s                  1 != L_7
#                      2000          2              1  = L_2
#  *                   2011  0.01s                  1 != L_2
#  *                   2036  0.01s                  0 != L_2
#  *                   2096  0.01s                  0  = L_3
#  *                   2098  0.01s                  0  = L_4
#  *                   2103  0.01s                  2  = L_3
#  *                   2107  0.01s                  2  = L_7
#  *                   2136  0.01s                  1 != L_2
#  *                   2156  0.02s                  1 != L_2
#  ! Time = 0.02s, Average fail depth = 5, Memory usage = 561.3 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   2173  0.02s                  0  = L_4
#  *                   2179  0.02s                  3 != L_3
#  *                   2189  0.02s                  0  = L_3
#  *                   2205  0.02s                  0  = L_2
#  *                   2212  0.02s                  1 != L_1
#  *                   2290  0.02s                  1 != L_7
#  *                   2299  0.02s                  2 != L_2
#  *                   2305  0.02s                  3 != L_2
#  *                   2315  0.02s                  0 != L_3
#  *                   2327  0.02s                  0  = L_2
#  *                   2338  0.02s                  0  = L_4
#  *                   2347  0.02s                  0  = L_3
#  *                   2353  0.02s                  0 != L_4
#  *                   2357  0.02s                  1  = L_4
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 92 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 2364
#  ! Number of fails        : 1091
#  ! Total memory usage     : 602.1 kB (562.0 kB CP Optimizer + 40.0 kB Concert)
#  ! Time spent in solve    : 0.02s (0.01s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 236400.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 8 IS 92 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 9 variables, 37 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 28.5 (before), 28.5 (after)
#  !  . Memory usage      : 299.3 kB (before), 299.3 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     14  0.01s                  6  = L_4
#  *                     57  0.01s                  4 != L_2
#  *                     66  0.01s                  5  = L_1
#  *                     86  0.01s                  4  = L_2
#  *                    130  0.01s                  1  = L_8
#  *                    134  0.01s                  1 != L_7
#  *                    157  0.01s                  1  = L_2
#  *                    169  0.01s                  1 != L_8
#  *                    178  0.01s                  1  = L_2
#  *                    220  0.01s                  7  = L_0
#  *                    221  0.01s                  7 != L_0
#  *                    230  0.01s                  7 != L_3
#  *                    265  0.01s                  1  = L_3
#  *                    296  0.01s                  1 != L_2
#  *                    314  0.01s                  2 != L_2
#  *                    317  0.01s                  4  = L_3
#  *                    333  0.01s                  1  = L_0
#  *                    359  0.01s                  2  = L_8
#  *                    382  0.01s                  1  = L_0
#  *                    467  0.01s                  3  = L_3
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 579.2 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    498  0.01s                  2  = L_0
#  *                    564  0.01s                  3 != L_7
#  *                    652  0.01s                  1  = L_7
#  *                    653  0.01s                  1 != L_7
#  *                    681  0.01s                  1 != L_0
#  *                    692  0.01s                  1  = L_8
#  *                    723  0.01s                  2 != L_0
#  *                    742  0.01s                  4 != L_3
#  *                    748  0.01s                  1 != L_3
#  *                    768  0.01s                  5  = L_8
#  *                    784  0.01s                  1  = L_8
#  *                    798  0.01s                  3  = L_7
#  *                    817  0.01s                  1  = L_7
#  *                    847  0.01s                  4 != L_7
#  *                    858  0.01s                  3 != L_3
#  *                    870  0.01s                  1  = L_2
#  *                    877  0.01s                  1  = L_7
#  *                    909  0.01s                  1  = L_8
#  *                    926  0.01s                  3  = L_0
#  *                    947  0.01s                  5  = L_2
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 579.2 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    948  0.01s                  5 != L_2
#  *                    959  0.01s                  1 != L_1
#                      1000          2              6  = L_3
#  *                   1023  0.01s                  1 != L_1
#  *                   1042  0.01s                  2 != L_2
#  *                   1064  0.01s                  2  = L_0
#  *                   1139  0.01s                  6  = L_8
#  *                   1158  0.01s                  2  = L_8
#  *                   1165  0.01s                  2  = L_0
#  *                   1176  0.01s                  2  = L_2
#  *                   1215  0.01s                  0 != L_4
#  *                   1223  0.01s                  0  = L_3
#  *                   1233  0.01s                  0  = L_8
#  *                   1245  0.01s                  5  = L_8
#  *                   1254  0.01s                  5 != L_2
#  *                   1269  0.01s                  0 != L_4
#  *                   1289  0.01s                  6  = L_6
#  *                   1307  0.01s                  0  = L_2
#  *                   1325  0.01s                  4 != L_4
#  *                   1352  0.01s                  0  = L_2
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1373  0.01s                  4 != L_6
#  *                   1377  0.01s                  0 != L_6
#  *                   1389  0.01s                  3 != L_6
#  *                   1421  0.01s                  0  = L_8
#  *                   1439  0.01s                  6 != L_6
#  *                   1465  0.01s                  3 != L_4
#  *                   1510  0.01s                  0  = L_2
#  *                   1526  0.01s                  0  = L_2
#  *                   1555  0.01s                  0  = L_8
#  *                   1600  0.01s                  3 != L_0
#  *                   1605  0.01s                  0  = L_3
#  *                   1638  0.01s                  4  = L_4
#  *                   1652  0.01s                  0  = L_3
#  *                   1684  0.01s                  0  = L_0
#  *                   1743  0.01s                  4 != L_6
#  *                   1746  0.01s                  0 != L_6
#  *                   1787  0.01s                  3 != L_4
#  *                   1791  0.01s                  3  = L_6
#  *                   1805  0.01s                  0  = L_1
#  *                   1822  0.01s                  0 != L_6
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1832  0.01s                  0  = L_2
#  *                   1842  0.01s                  0  = L_0
#  *                   1868  0.01s                  5 != L_6
#  *                   1873  0.01s                  3  = L_6
#  *                   1929  0.01s                  5 != L_4
#  *                   1944  0.01s                  2  = L_0
#  *                   1945  0.01s                  2 != L_0
#                      2000          2              7  = L_7
#  *                   2020  0.01s                  0  = L_1
#  *                   2119  0.02s                  0 != L_2
#  *                   2180  0.02s                  4  = L_0
#  *                   2204  0.02s                  0 != L_3
#  *                   2231  0.02s                  0 != L_4
#  *                   2247  0.02s                  0  = L_2
#  *                   2317  0.02s                  4 != L_6
#  *                   2351  0.02s                  1  = L_2
#  *                   2360  0.02s                  1  = L_1
#  *                   2372  0.02s                  1 != L_6
#  *                   2376  0.02s                  1  = L_2
#  *                   2381  0.02s                  1  = L_2
#  ! Time = 0.02s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   2414  0.02s                  1  = L_1
#  *                   2415  0.02s                  1 != L_1
#  *                   2426  0.02s                  4 != L_1
#  *                   2429  0.02s                  1 != L_8
#  *                   2487  0.02s                  0  = L_2
#  *                   2490  0.02s                  0  = L_6
#  *                   2567  0.02s                  0 != L_1
#  *                   2588  0.02s                  0 != L_7
#  *                   2601  0.02s                  0 != L_3
#  *                   2658  0.02s                  1  = L_3
#  *                   2734  0.02s                  0  = L_6
#  *                   2753  0.02s                  0 != L_3
#  *                   2762  0.02s                  0  = L_2
#  *                   2833  0.02s                  1  = L_8
#  *                   2834  0.02s                  1 != L_8
#  *                   2896  0.02s                  0  = L_2
#  *                   2934  0.02s                  3 != L_3
#  *                   2935  0.02s                  5 != L_1
#  *                   2943  0.02s                  0  = L_8
#  *                   2961  0.02s                  5  = L_0
#  ! Time = 0.02s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   2966  0.02s                  3  = L_2
#                      3000          2        F     6 != L_7
#  *                   3004  0.02s                  6  = L_2
#  *                   3059  0.02s                  3 != L_1
#  *                   3079  0.02s                  1 != L_6
#  *                   3090  0.02s                  3  = L_8
#  *                   3091  0.02s                  3 != L_8
#  *                   3143  0.02s                  1 != L_6
#  *                   3147  0.02s                  0 != L_6
#  *                   3155  0.02s                  1  = L_2
#  *                   3167  0.02s                  0 != L_7
#  *                   3180  0.02s                  3 != L_2
#  *                   3186  0.02s                  0  = L_2
#  *                   3231  0.02s                  1 != L_6
#  *                   3256  0.02s                  5 != L_6
#  *                   3269  0.02s                  1  = L_2
#  *                   3271  0.02s                  2 != L_7
#  *                   3368  0.02s                  2  = L_3
#  *                   3401  0.02s                  0  = L_4
#  *                   3471  0.02s                  0 != L_4
#  ! Time = 0.02s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   3486  0.02s                  4 != L_1
#  *                   3505  0.02s                  2 != L_4
#  *                   3523  0.02s                  5  = L_4
#  *                   3533  0.02s                  1  = L_4
#  *                   3582  0.02s                  0 != L_2
#  *                   3615  0.02s                  0  = L_4
#  *                   3692  0.03s                  1 != L_3
#  *                   3722  0.03s                  6  = L_3
#  *                   3736  0.03s                  0 != L_2
#  *                   3836  0.03s                  0  = L_6
#  *                   3849  0.03s                  0  = L_6
#  *                   3867  0.03s                  1 != L_8
#  *                   3931  0.03s                  4 != L_2
#  *                   3949  0.03s                  4  = L_2
#                      4000          2        F     1  = L_7
#  *                   4041  0.03s                  1  = L_6
#  *                   4043  0.03s                  2 != L_8
#  *                   4074  0.03s                  1  = L_6
#  *                   4079  0.03s                  2  = L_8
#  *                   4206  0.03s                  1  = L_4
#  ! Time = 0.03s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   4237  0.03s                  2 != L_8
#  *                   4243  0.03s                  1  = L_4
#  *                   4271  0.03s                  1 != L_2
#  *                   4277  0.03s                  1  = L_2
#  *                   4300  0.03s                  0  = L_4
#  *                   4308  0.03s                  1 != L_3
#  *                   4339  0.03s                  1  = L_8
#  *                   4352  0.03s                  0  = L_4
#  *                   4411  0.03s                  0  = L_3
#  *                   4426  0.03s                  5  = L_6
#  *                   4463  0.03s                  6  = L_0
#  *                   4475  0.03s                  3  = L_0
#  *                   4621  0.03s                  0  = L_4
#  *                   4643  0.03s                  1 != L_8
#  *                   4664  0.03s                  0  = L_0
#  *                   4670  0.03s                  5  = L_0
#  *                   4718  0.03s                  1 != L_4
#  *                   4766  0.03s                  0  = L_3
#  *                   4794  0.03s                  5 != L_7
#  *                   4905  0.03s                  5  = L_7
#  ! Time = 0.03s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   4970  0.03s                  2  = L_2
#                      5000          2              1  = L_0
#  *                   5077  0.03s                  0  = L_7
#  *                   5105  0.03s                  0  = L_7
#  *                   5149  0.03s                  2 != L_3
#  *                   5195  0.03s                  3 != L_6
#  *                   5204  0.03s                  1 != L_0
#  *                   5221  0.03s                  0  = L_8
#  *                   5242  0.03s                  5  = L_8
#  *                   5395  0.03s                  3 != L_4
#  *                   5407  0.03s                  2 != L_3
#  *                   5447  0.03s                  2 != L_6
#  *                   5464  0.04s                  3  = L_6
#  *                   5511  0.04s                  0  = L_6
#  *                   5522  0.04s                  0  = L_2
#  *                   5540  0.04s                  0 != L_4
#  *                   5546  0.04s                  0  = L_3
#  *                   5569  0.04s                  3 != L_2
#  *                   5580  0.04s                  3 != L_8
#  *                   5605  0.04s                  1  = L_3
#  ! Time = 0.04s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   5611  0.04s                  4  = L_8
#  *                   5638  0.04s                  1 != L_4
#  *                   5726  0.04s                  1 != L_8
#  *                   5735  0.04s                  4 != L_3
#  *                   5790  0.04s                  1 != L_4
#  *                   5801  0.04s                  1 != L_4
#  *                   5835  0.04s                  0  = L_4
#  *                   5854  0.04s                  1 != L_6
#  *                   5917  0.04s                  0  = L_3
#  *                   5937  0.04s                  0  = L_7
#  *                   5949  0.04s                  3 != L_6
#                      6000          2        F     1  = L_2
#  *                   6016  0.04s                  4  = L_8
#  *                   6019  0.04s                  0  = L_8
#  *                   6071  0.04s                  3 != L_2
#  *                   6118  0.04s                  4  = L_7
#  *                   6121  0.04s                  2 != L_3
#  *                   6170  0.04s                  1  = L_3
#  *                   6175  0.04s                  0 != L_4
#  *                   6212  0.04s                  0 != L_6
#  ! Time = 0.04s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   6223  0.04s                  0 != L_8
#  *                   6244  0.04s                  4  = L_8
#  *                   6294  0.04s                  0  = L_8
#  *                   6340  0.04s                  1 != L_3
#  *                   6446  0.04s                  0  = L_7
#  *                   6448  0.04s                  1 != L_2
#  *                   6458  0.04s                  0  = L_6
#  *                   6508  0.04s                  0  = L_6
#  *                   6548  0.04s                  4 != L_8
#  *                   6564  0.04s                  7  = L_8
#  *                   6579  0.04s                  5  = L_0
#  *                   6592  0.04s                  1  = L_2
#  *                   6609  0.04s                  5 != L_1
#  *                   6615  0.04s                  2 != L_4
#  *                   6642  0.04s                  2  = L_8
#  *                   6688  0.04s                  2  = L_3
#  *                   6716  0.04s                  0  = L_4
#  *                   6723  0.04s                  0  = L_1
#  *                   6726  0.04s                  0  = L_3
#  *                   6754  0.04s                  0 != L_8
#  ! Time = 0.04s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   6928  0.04s                  1  = L_4
#  *                   6972  0.04s                  5 != L_6
#                      7000          2              1  = L_4
#  *                   7052  0.04s                  1 != L_4
#  *                   7108  0.04s                  0  = L_6
#  *                   7151  0.04s                  2  = L_3
#  *                   7181  0.04s                  1  = L_8
#  *                   7182  0.04s                  1 != L_8
#  *                   7199  0.04s                  0  = L_6
#  *                   7228  0.04s                  5 != L_8
#  *                   7243  0.04s                  5  = L_8
#  *                   7308  0.04s                  0 != L_3
#  *                   7329  0.04s                  0  = L_4
#  *                   7344  0.04s                  0  = L_6
#  *                   7386  0.04s                  7 != L_8
#  *                   7396  0.04s                  1 != L_8
#  *                   7432  0.04s                  4  = L_0
#  *                   7440  0.04s                  0 != L_6
#  *                   7471  0.04s                  3 != L_0
#  *                   7492  0.04s                  4  = L_4
#  ! Time = 0.04s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   7500  0.04s                  1 != L_8
#  *                   7507  0.04s                  1  = L_3
#  *                   7592  0.04s                  0 != L_2
#  *                   7597  0.04s                  0  = L_1
#  *                   7606  0.04s                  0  = L_4
#  *                   7673  0.04s                  1 != L_6
#  *                   7681  0.04s                  0 != L_2
#  *                   7761  0.04s                  1 != L_2
#  *                   7777  0.04s                  5 != L_0
#  *                   7806  0.04s                  1  = L_3
#  *                   7829  0.04s                  1  = L_4
#  *                   7911  0.04s                  0 != L_6
#                      8000          2        F     2  = L_3
#  *                   8005  0.04s                  3  = L_8
#  *                   8078  0.04s                  3  = L_0
#  *                   8079  0.04s                  3 != L_0
#  *                   8098  0.04s                  0  = L_4
#  *                   8105  0.04s                  1  = L_0
#  *                   8121  0.04s                  3 != L_2
#  *                   8152  0.04s                  3 != L_0
#  ! Time = 0.04s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   8162  0.04s                  0  = L_6
#  *                   8174  0.04s                  4 != L_0
#  *                   8187  0.04s                  5 != L_8
#  *                   8188  0.04s                  6 != L_3
#  *                   8212  0.04s                  2  = L_3
#  *                   8275  0.04s                  5 != L_1
#  *                   8277  0.04s                  1  = L_6
#  *                   8322  0.04s                  1 != L_0
#  *                   8357  0.04s                  4 != L_3
#  *                   8364  0.04s                  0 != L_1
#  *                   8409  0.04s                  4 != L_3
#  *                   8414  0.04s                  1 != L_6
#  *                   8479  0.04s                  0  = L_6
#  *                   8488  0.04s                  6  = L_8
#  *                   8500  0.05s                  1  = L_1
#  *                   8578  0.05s                  1 != L_1
#  *                   8598  0.05s                  1  = L_6
#  *                   8623  0.05s                  2 != L_8
#  *                   8658  0.05s                  1 != L_1
#  *                   8667  0.05s                  4  = L_0
#  ! Time = 0.05s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   8670  0.05s                  3 != L_2
#  *                   8692  0.05s                  5 != L_2
#  *                   8708  0.05s                  5 != L_2
#  *                   8735  0.05s                  0  = L_4
#  *                   8765  0.05s                  1  = L_6
#  *                   8782  0.05s                  0  = L_0
#  *                   8796  0.05s                  0 != L_4
#  *                   8801  0.05s                  1 != L_8
#  *                   8814  0.05s                  1 != L_8
#  *                   8820  0.05s                  1 != L_4
#  *                   8827  0.05s                  1  = L_4
#  *                   8864  0.05s                  1  = L_1
#  *                   8874  0.05s                  5 != L_0
#  *                   8888  0.05s                  0  = L_1
#  *                   8905  0.05s                  0  = L_2
#  *                   8977  0.05s                  5 != L_0
#  *                   8991  0.05s                  2 != L_2
#                      9000          2        F     1  = L_8
#  *                   9026  0.05s                  4 != L_7
#  *                   9031  0.05s                  1  = L_2
#  ! Time = 0.05s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   9061  0.05s                  1  = L_8
#  *                   9062  0.05s                  1 != L_8
#  *                   9103  0.05s                  1 != L_2
#  *                   9112  0.05s                  2  = L_3
#  *                   9142  0.05s                  3 != L_2
#  *                   9174  0.05s                  3 != L_2
#  *                   9183  0.05s                  2 != L_8
#  *                   9194  0.05s                  3 != L_7
#  *                   9207  0.05s                  4 != L_8
#  *                   9230  0.05s                  0  = L_3
#  *                   9246  0.05s                  4 != L_7
#  *                   9264  0.05s                  3 != L_3
#  *                   9288  0.05s                  3 != L_3
#  *                   9329  0.05s                  4  = L_7
#  *                   9360  0.05s                  0  = L_3
#  *                   9364  0.05s                  0 != L_0
#  *                   9373  0.05s                  1 != L_8
#  *                   9397  0.05s                  1  = L_7
#  *                   9398  0.05s                  1 != L_7
#  *                   9486  0.05s                  1  = L_7
#  ! Time = 0.05s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   9555  0.05s                  1  = L_1
#  *                   9583  0.05s                  0  = L_7
#  *                   9656  0.05s                  4 != L_0
#  *                   9695  0.05s                  6 != L_2
#  *                   9708  0.05s                  3  = L_3
#  *                   9731  0.05s                  0 != L_3
#  *                   9733  0.05s                  0  = L_2
#  *                   9743  0.05s                  0  = L_3
#  *                   9785  0.05s                  0  = L_0
#  *                   9795  0.05s                  4 != L_7
#  *                   9819  0.05s                  1  = L_3
#  *                   9823  0.06s                  0  = L_2
#  *                   9863  0.06s                  1  = L_7
#  *                   9871  0.06s                  0  = L_8
#  *                   9877  0.06s                  1  = L_3
#  *                   9908  0.06s                  0 != L_2
#  *                   9910  0.06s                  3 != L_8
#  *                   9954  0.06s                  1 != L_2
#  *                   9961  0.06s                  4  = L_7
#  *                   9977  0.06s                  0  = L_2
#  ! Time = 0.06s, Average fail depth = 6, Memory usage = 579.5 kB
#  !               Branches  Non-fixed            Branch decision
#                     10000          2        F     2 != L_3
#  *                  10001  0.06s                  0 != L_4
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 352 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 10022
#  ! Number of fails        : 4660
#  ! Total memory usage     : 620.4 kB (580.2 kB CP Optimizer + 40.1 kB Concert)
#  ! Time spent in solve    : 0.06s (0.06s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 200440.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 9 IS 352 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 10 variables, 46 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 33.2 (before), 33.2 (after)
#  !  . Memory usage      : 299.3 kB (before), 299.3 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                    105  0.01s                  6  = L_3
#  *                    172  0.01s                  6 != L_9
#  *                    230  0.01s                  1 != L_7
#  *                    365  0.01s                  1 != L_1
#  *                    398  0.01s                  6 != L_0
#  *                    442  0.01s                  1  = L_3
#  *                    467  0.01s                  1  = L_2
#  *                    482  0.01s                  1 != L_3
#  *                    545  0.01s                  1  = L_9
#  *                    603  0.01s                  3  = L_9
#  *                    604  0.01s                  3 != L_9
#  *                    613  0.01s                  5 != L_2
#  *                    639  0.01s                  1 != L_2
#  *                    666  0.01s                  1  = L_3
#  *                    689  0.01s                  3 != L_9
#  *                    700  0.01s                  1 != L_9
#  *                    706  0.01s                  7  = L_1
#  *                    709  0.01s                  7  = L_7
#  *                    750  0.01s                  7 != L_8
#  *                    837  0.01s                  5 != L_7
#  ! Time = 0.01s, Average fail depth = 7, Memory usage = 599.1 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    883  0.01s                  1  = L_2
#  *                    891  0.01s                  1 != L_8
#  *                    956  0.01s                  1  = L_7
#                      1000          2              2  = L_9
#  *                   1017  0.01s                  5 != L_9
#  *                   1031  0.01s                  5 != L_9
#  *                   1054  0.01s                  1  = L_2
#  *                   1056  0.01s                  5 != L_3
#  *                   1150  0.01s                  1 != L_3
#  *                   1158  0.01s                  1  = L_9
#  *                   1204  0.01s                  2  = L_2
#  *                   1252  0.01s                  6  = L_0
#  *                   1256  0.01s                  1  = L_7
#  *                   1262  0.01s                  1  = L_3
#  *                   1360  0.01s                  6 != L_3
#  *                   1411  0.01s                  1  = L_0
#  *                   1624  0.01s                  3 != L_7
#  *                   1729  0.01s                  5  = L_9
#  *                   1784  0.01s                  5 != L_2
#  *                   1856  0.01s                  3 != L_4
#  ! Time = 0.01s, Average fail depth = 7, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1890  0.01s                  4 != L_7
#  *                   1903  0.01s                  1  = L_7
#  *                   1979  0.01s                  2  = L_1
#  *                   1983  0.01s                  2  = L_8
#                      2000          2              3  = L_9
#  *                   2119  0.01s                  3 != L_9
#  *                   2184  0.01s                  4  = L_3
#  *                   2233  0.01s                  1  = L_7
#  *                   2268  0.01s                  1 != L_3
#  *                   2293  0.01s                  4 != L_0
#  *                   2309  0.02s                  1 != L_0
#  *                   2338  0.02s                  7 != L_0
#  *                   2344  0.02s                  1  = L_2
#  *                   2472  0.02s                  1  = L_7
#  *                   2570  0.02s                  2  = L_8
#  *                   2571  0.02s                  2 != L_8
#  *                   2572  0.02s                  3 != L_4
#  *                   2703  0.02s                  2  = L_4
#  *                   2718  0.02s                  1 != L_2
#  *                   2775  0.02s                  1  = L_8
#  ! Time = 0.02s, Average fail depth = 7, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   2814  0.02s                  1  = L_7
#  *                   2827  0.02s                  3 != L_1
#  *                   2835  0.02s                  5 != L_9
#  *                   2849  0.02s                  8 != L_1
#  *                   2932  0.02s                  1  = L_9
#  *                   2946  0.02s                  1 != L_3
#  *                   2954  0.02s                  5 != L_3
#  *                   2966  0.02s                  1  = L_7
#                      3000          2        F     1  = L_7
#  *                   3092  0.02s                  1  = L_2
#  *                   3140  0.02s                  5 != L_3
#  *                   3290  0.02s                  1  = L_2
#  *                   3345  0.02s                  3  = L_7
#  *                   3443  0.02s                  2 != L_2
#  *                   3506  0.02s                  5 != L_8
#  *                   3527  0.02s                  3  = L_0
#  *                   3633  0.02s                  4 != L_3
#  *                   3661  0.02s                  4 != L_3
#  *                   3826  0.02s                  1  = L_0
#  *                   3843  0.02s                  1  = L_3
#  ! Time = 0.02s, Average fail depth = 7, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   3844  0.02s                  1 != L_3
#  *                   3860  0.02s                  1  = L_2
#  *                   3875  0.02s                  1 != L_1
#  *                   3882  0.02s                  2 != L_8
#  *                   3968  0.02s                  1  = L_8
#  *                   3990  0.02s                  4  = L_7
#                      4000          2              1 != L_9
#  *                   4035  0.02s                  2  = L_1
#  *                   4077  0.02s                  1  = L_3
#  *                   4136  0.02s                  2  = L_0
# ...
#  *                  35540  0.15s                  1 != L_6
#  *                  35577  0.15s                  2  = L_6
#  ! Time = 0.15s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  35722  0.15s                  3 != L_0
#  *                  35791  0.15s                  6 != L_1
#  *                  35794  0.15s                  0  = L_1
#  *                  35810  0.15s                  0 != L_6
#  *                  35829  0.15s                  8  = L_2
#  *                  35851  0.15s                  0  = L_2
#  *                  35990  0.15s                  3  = L_2
#  *                  35991  0.15s                  3 != L_2
#                     36000          2        F     0  = L_6
#  *                  36008  0.15s                  3  = L_2
#  *                  36014  0.15s                  0  = L_3
#  *                  36035  0.15s                  0  = L_3
#  *                  36036  0.15s                  0 != L_3
#  *                  36210  0.15s                  6 != L_0
#  *                  36236  0.15s                  1 != L_7
#  *                  36253  0.15s                  0  = L_3
#  *                  36295  0.15s                  2 != L_2
#  *                  36310  0.15s                  3 != L_2
#  *                  36338  0.15s                  0 != L_3
#  *                  36382  0.15s                  1 != L_0
#  ! Time = 0.15s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  36392  0.15s                  1 != L_2
#  *                  36414  0.15s                  1 != L_1
#  *                  36461  0.15s                  0 != L_7
#  *                  36500  0.15s                  1  = L_0
#  *                  36640  0.15s                  0  = L_1
#  *                  36802  0.15s                  0  = L_0
#  *                  36858  0.15s                  1 != L_0
#  *                  36873  0.15s                  2 != L_4
#                     37000          2              1  = L_6
#  *                  37039  0.15s                  1  = L_1
#  *                  37503  0.15s                  0 != L_7
#  *                  37738  0.15s                  0 != L_7
#  *                  37830  0.16s                  0  = L_7
#  *                  37925  0.16s                  0 != L_2
#  *                  37930  0.16s                  0  = L_6
#                     38000          2              0 != L_6
#  *                  38051  0.16s                  5  = L_8
#  *                  38233  0.16s                  0 != L_1
#  *                  38270  0.16s                  0  = L_6
#  *                  38589  0.16s                  0  = L_4
#  ! Time = 0.16s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  38646  0.16s                  0 != L_1
#  *                  38703  0.16s                  7 != L_7
#  *                  38714  0.16s                  1  = L_9
#  *                  38720  0.16s                  6 != L_1
#  *                  38734  0.16s                  5 != L_0
#  *                  38754  0.16s                  6  = L_6
#  *                  38809  0.16s                  1 != L_8
#  *                  38977  0.16s                  1  = L_6
#  *                  38988  0.16s                  6 != L_8
#                     39000          2        F     1  = L_6
#  *                  39190  0.16s                  1  = L_6
#  *                  39330  0.16s                  2 != L_1
#  *                  39362  0.16s                  2  = L_1
#  *                  39363  0.16s                  2 != L_1
#  *                  39396  0.16s                  0  = L_0
#  *                  39540  0.16s                  0 != L_2
#  *                  39659  0.16s                  0  = L_8
#                     40000          2              3  = L_9
#  *                  40025  0.16s                  0 != L_8
#  *                  40041  0.16s                  1 != L_2
#  ! Time = 0.16s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  40057  0.16s                  0 != L_9
#  *                  40071  0.16s                  0 != L_9
#  *                  40104  0.16s                  0  = L_4
#  *                  40312  0.16s                  1  = L_9
#  *                  40400  0.16s                  1  = L_0
#  *                  40467  0.17s                  2 != L_2
#  *                  40520  0.17s                  1  = L_6
#  *                  40524  0.17s                  1  = L_4
#  *                  40642  0.17s                  0 != L_8
#  *                  40735  0.17s                  6 != L_8
#  *                  40767  0.17s                  4  = L_6
#  *                  40782  0.17s                  0 != L_0
#  *                  40844  0.17s                  7 != L_0
#  *                  40851  0.17s                  2  = L_8
#  *                  40864  0.17s                  2  = L_7
#                     41000          2              4 != L_0
#  *                  41010  0.17s                  1  = L_4
#  *                  41012  0.17s                  2 != L_1
#  *                  41087  0.17s                  6  = L_6
#  *                  41192  0.17s                  5  = L_6
#  ! Time = 0.17s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  41215  0.17s                  3 != L_2
#  *                  41438  0.17s                  0  = L_9
#  *                  41667  0.17s                  1 != L_7
#  *                  41681  0.17s                  2 != L_7
#  *                  41781  0.17s                  0  = L_0
#  *                  41843  0.17s                  0  = L_4
#  *                  41881  0.17s                  0  = L_9
#  *                  41921  0.17s                  2 != L_0
#  *                  41927  0.17s                  2 != L_0
#  *                  41966  0.17s                  0  = L_9
#  *                  41969  0.17s                  2 != L_0
#                     42000          2        F     2 != L_1
#  *                  42038  0.17s                  0  = L_6
#  *                  42051  0.17s                  0  = L_4
#  *                  42287  0.17s                  4 != L_0
#  *                  42429  0.17s                  0  = L_1
#  *                  42580  0.17s                  3  = L_7
#  *                  42611  0.18s                  4  = L_6
#  *                  42627  0.18s                  4  = L_0
#  *                  42673  0.18s                  0  = L_7
#  ! Time = 0.18s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  42701  0.18s                  4  = L_6
#  *                  42707  0.18s                  4 != L_2
#  *                  42799  0.18s                  0 != L_2
#  *                  42836  0.18s                  0 != L_2
#  *                  42893  0.18s                  1 != L_8
#                     43000          2        F     6  = L_4
#  *                  43218  0.18s                  0 != L_7
#  *                  43266  0.18s                  0  = L_4
#  *                  43307  0.18s                  4 != L_8
#  *                  43317  0.18s                  0  = L_9
#  *                  43439  0.18s                  0  = L_2
#  *                  43459  0.18s                  0 != L_9
#  *                  43474  0.18s                  0 != L_7
#  *                  43498  0.18s                  0 != L_1
#  *                  43514  0.18s                  2 != L_6
#  *                  43515  0.18s                  3 != L_9
#  *                  43526  0.18s                  6 != L_8
#  *                  43548  0.18s                  1  = L_8
#  *                  43622  0.18s                  2  = L_4
#  *                  43624  0.18s                  2  = L_8
#  ! Time = 0.18s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  43686  0.18s                  0  = L_9
#  *                  43765  0.18s                  1 != L_2
#  *                  43782  0.18s                  0 != L_9
#  *                  43793  0.18s                  4 != L_7
#  *                  43878  0.18s                  1  = L_7
#  *                  43920  0.18s                  1  = L_8
#  *                  43927  0.18s                  2 != L_7
#  *                  43928  0.18s                  1 != L_2
#  *                  43948  0.18s                  2 != L_8
#  *                  44000  0.18s                  2  = L_2
#                     44000          2        F        -
#  *                  44020  0.18s                  0  = L_8
#  *                  44025  0.18s                  0  = L_8
#  *                  44043  0.18s                  0  = L_9
#  *                  44049  0.18s                  0  = L_2
#  *                  44079  0.18s                  0  = L_7
#  *                  44165  0.18s                  2  = L_8
#  *                  44169  0.18s                  2  = L_1
#  *                  44179  0.18s                  3 != L_2
#  *                  44202  0.18s                  3  = L_0
#  ! Time = 0.18s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  44205  0.18s                  2 != L_8
#  *                  44213  0.18s                  3 != L_0
#  *                  44296  0.18s                  6 != L_7
#  *                  44319  0.18s                  1  = L_7
#  *                  44349  0.18s                  1  = L_1
#  *                  44433  0.18s                  1  = L_2
#  *                  44455  0.18s                  1  = L_1
#  *                  44463  0.18s                  2 != L_1
#  *                  44540  0.18s                  5 != L_7
#  *                  44543  0.18s                  1 != L_0
#  *                  44602  0.18s                  4 != L_1
#  *                  44608  0.18s                  3  = L_0
#  *                  44609  0.18s                  3 != L_0
#  *                  44628  0.18s                  3 != L_0
#  *                  44632  0.18s                  6  = L_9
#  *                  44635  0.18s                  1  = L_2
#  *                  44658  0.18s                  1  = L_2
#  *                  44696  0.18s                  1  = L_1
#  *                  44737  0.18s                  2  = L_7
#  *                  44740  0.18s                  2 != L_9
#  ! Time = 0.18s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  44741  0.18s                  6 != L_1
#  *                  44813  0.18s                  4 != L_2
#  *                  44880  0.18s                  0  = L_7
#  *                  44939  0.18s                  0  = L_7
#  *                  44949  0.18s                  0 != L_3
#  *                  44959  0.18s                  0  = L_2
#                     45000          2        F     0  = L_2
#  *                  45003  0.18s                  0  = L_2
#  *                  45102  0.18s                  3  = L_7
#  *                  45144  0.18s                  5 != L_7
#  *                  45197  0.18s                  2  = L_7
#  *                  45443  0.18s                  1 != L_3
#  *                  45568  0.18s                  4 != L_9
#  *                  45581  0.18s                  7 != L_1
#  *                  45623  0.18s                  3  = L_1
#  *                  45645  0.18s                  3  = L_1
#  *                  45679  0.18s                  0  = L_9
#  *                  45692  0.18s                  0  = L_9
#  *                  45724  0.18s                  0  = L_0
#  *                  45745  0.18s                  0  = L_7
#  ! Time = 0.18s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  45766  0.18s                  1 != L_2
#  *                  45775  0.18s                  0  = L_0
#  *                  45788  0.18s                  5 != L_7
#  *                  45835  0.18s                  2  = L_2
#  *                  45863  0.18s                  5 != L_8
#  *                  45893  0.19s                  4  = L_1
#                     46000          2              5  = L_7
#  *                  46239  0.19s                  3 != L_3
#  *                  46306  0.19s                  2  = L_3
#  *                  46377  0.19s                  0  = L_3
#  *                  46407  0.19s                  0  = L_9
#  *                  46660  0.19s                  3 != L_3
#  *                  46683  0.19s                  2 != L_2
#  *                  46767  0.19s                  0 != L_7
#  *                  46816  0.19s                  1  = L_9
#  *                  46909  0.19s                  3 != L_0
#  *                  46924  0.19s                  0 != L_1
#  *                  46957  0.19s                  4 != L_2
#                     47000          2              0 != L_2
#  *                  47146  0.19s                  4 != L_3
#  ! Time = 0.19s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  47149  0.19s                  3 != L_2
#  *                  47192  0.19s                  0 != L_2
#  *                  47270  0.19s                  1 != L_1
#  *                  47307  0.19s                  2 != L_7
#  *                  47312  0.19s                  4  = L_8
#  *                  47403  0.19s                  1  = L_3
#  *                  47412  0.19s                  1  = L_3
#  *                  47420  0.19s                  3  = L_3
#  *                  47435  0.19s                  4 != L_9
#  *                  47523  0.19s                  0  = L_1
#  *                  47533  0.19s                  0  = L_9
#  *                  47594  0.19s                  4  = L_8
#  *                  47595  0.19s                  4 != L_8
#  *                  47653  0.19s                  0 != L_2
#  *                  47677  0.19s                  0 != L_0
#  *                  47719  0.19s                  0 != L_8
#  *                  47788  0.19s                  3 != L_8
#  *                  47883  0.19s                  5  = L_0
#                     48000          2        F     2  = L_2
#  *                  48006  0.19s                  0  = L_9
#  ! Time = 0.19s, Average fail depth = 6, Memory usage = 599.5 kB
#  !               Branches  Non-fixed            Branch decision
#  *                  48051  0.19s                  3  = L_1
#  *                  48063  0.19s                  1 != L_7
#  *                  48133  0.19s                  1  = L_9
#  *                  48157  0.19s                  1  = L_2
#  *                  48166  0.19s                  2  = L_2
#  *                  48266  0.19s                  4 != L_2
#  *                  48270  0.19s                  1  = L_2
#  *                  48281  0.19s                  3 != L_7
#  *                  48319  0.19s                  5  = L_3
#  *                  48432  0.20s                  1 != L_9
#  *                  48467  0.20s                  2  = L_7
#  *                  48470  0.20s                  0 != L_1
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 724 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 48470
#  ! Number of fails        : 23512
#  ! Total memory usage     : 640.4 kB (600.2 kB CP Optimizer + 40.2 kB Concert)
#  ! Time spent in solve    : 0.20s (0.19s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 256455.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 10 IS 724 ****

# %% [markdown]
# ### 1.2. Model with global constraints

# %% [markdown]
# **Exercice:** Create a function `global_constraint_model(N)` that models and returns an instance of `CpoModel` for the n-queens problem with `N` queens, using **only** and exaclty 3 global constraints.

# %%
def global_constraint_model(N):
    mdl=CpoModel()
    L=mdl.integer_var_list(N,0,N-1,"L")
    mdl.add(all_diff(L))
    mdl.add(all_diff([L[i]+i for i in range(N)]))
    mdl.add(all_diff([L[i]-i for i in range(N)]))
    return mdl

# %% [markdown]
# **Exercice:** Test your function by solving the n-queens problem for small values of $N$ ($N < 20$).

# %%
N=5
mdl=global_constraint_model(N)
sol=mdl.solve()

allvars=sol.get_all_var_solutions()
display.n_queens(allvars)
# %matplotlib inline
#mdl.export_model()
# Out:
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 5 variables, 3 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 11.6 (before), 11.6 (after)
#  !  . Memory usage      : 267.0 kB (before), 267.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      3  0.01s                  1  = L_4
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 3
#  ! Number of fails        : 0
#  ! Total memory usage     : 688.9 kB (649.1 kB CP Optimizer + 39.8 kB Concert)
#  ! Time spent in solve    : 0.01s (0.00s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 300.0
#  ! ----------------------------------------------------------------------------

# %% [markdown]
# **Question**: How many solutions are there for $N = 3,~\ldots,~10$?
#
# **Important:** You should obtain the same number as the previous model!

# %%
for N in range(3,11):
    mdl=global_constraint_model(N)
    lsols = mdl.start_search(SearchType="DepthFirst")
    print("         **** THE NUMBER OF SOLUTIONS FOR N =",N,"IS",count_iterable(lsols),"****")
# Out:
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 3 variables, 3 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 4.8 (before), 4.8 (after)
#  !  . Memory usage      : 266.9 kB (before), 266.9 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  ! ----------------------------------------------------------------------------
#  ! Search completed, model has no solution.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 4
#  ! Number of fails        : 3
#  ! Total memory usage     : 535.8 kB (496.2 kB CP Optimizer + 39.6 kB Concert)
#  ! Time spent in solve    : 0.01s (0.00s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 400.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 3 IS 0 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 4 variables, 3 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 8.0 (before), 8.0 (after)
#  !  . Memory usage      : 267.0 kB (before), 267.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      2  0.01s                  2  = L_0
#  *                     10  0.01s                  0 != L_0
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 2 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 10
#  ! Number of fails        : 4
#  ! Total memory usage     : 570.2 kB (530.4 kB CP Optimizer + 39.7 kB Concert)
#  ! Time spent in solve    : 0.01s (0.01s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 1000.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 4 IS 2 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 5 variables, 3 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 11.6 (before), 11.6 (after)
#  !  . Memory usage      : 267.0 kB (before), 267.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      2  0.01s                  1  = L_1
#  *                      5  0.01s                  3 != L_1
#  *                      8  0.01s                  3  = L_4
#  *                      9  0.01s                  3 != L_4
#  *                     12  0.01s                  0  = L_2
#  *                     13  0.01s                  0 != L_2
#  *                     16  0.01s                  0  = L_4
#  *                     17  0.01s                  0 != L_4
#  *                     21  0.01s                  1  = L_2
#  *                     22  0.01s                  1 != L_2
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 10 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 22
#  ! Number of fails        : 2
#  ! Total memory usage     : 571.9 kB (532.1 kB CP Optimizer + 39.8 kB Concert)
#  ! Time spent in solve    : 0.01s (0.01s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 2200.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 5 IS 10 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 6 variables, 3 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 15.5 (before), 15.5 (after)
#  !  . Memory usage      : 267.1 kB (before), 267.1 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     17  0.01s                  0  = L_2
#  *                     30  0.01s                  3 != L_2
#  *                     42  0.01s                  2 != L_3
#  *                     63  0.01s                  1 != L_1
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 4 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 74
#  ! Number of fails        : 34
#  ! Total memory usage     : 574.0 kB (534.1 kB CP Optimizer + 39.9 kB Concert)
#  ! Time spent in solve    : 0.01s (0.00s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 7400.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 6 IS 4 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 7 variables, 3 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 19.7 (before), 19.7 (after)
#  !  . Memory usage      : 267.1 kB (before), 267.1 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      3  0.01s                  2  = L_1
#  *                      6  0.01s                  5 != L_1
#  *                     11  0.01s                  2  = L_6
#  *                     12  0.01s                  2 != L_6
#  *                     15  0.01s                  2  = L_4
#  *                     19  0.01s                  2  = L_4
#  *                     25  0.01s                  2  = L_2
#  *                     34  0.01s                  2 != L_3
#  *                     42  0.01s                  0 != L_3
#  *                     46  0.01s                  2  = L_0
#  *                     52  0.01s                  3  = L_4
#  *                     61  0.01s                  3  = L_1
#  *                     67  0.01s                  3  = L_2
#  *                     75  0.01s                  3  = L_1
#  *                     77  0.01s                  0  = L_2
#  *                     78  0.01s                  0 != L_2
#  *                     80  0.01s                  1  = L_3
#  *                     92  0.01s                  2 != L_2
#  *                     97  0.01s                  4  = L_1
#  *                    102  0.01s                  0 != L_0
#  ! Time = 0.01s, Average fail depth = 4, Memory usage = 537.0 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    107  0.01s                  1 != L_4
#  *                    112  0.01s                  0 != L_4
#  *                    114  0.01s                  1  = L_2
#  *                    126  0.01s                  1  = L_6
#  *                    127  0.01s                  1 != L_6
#  *                    135  0.01s                  3  = L_2
#  *                    140  0.01s                  0  = L_2
#  *                    141  0.01s                  0 != L_2
#  *                    146  0.01s                  2  = L_2
#  *                    154  0.01s                  1 != L_4
#  *                    162  0.01s                  0 != L_3
#  *                    167  0.01s                  3  = L_1
#  *                    173  0.01s                  2  = L_3
#  *                    178  0.01s                  1  = L_6
#  *                    185  0.01s                  3 != L_3
#  *                    188  0.01s                  1  = L_4
#  *                    194  0.01s                  2  = L_6
#  *                    200  0.01s                  3  = L_6
#  *                    201  0.01s                  3 != L_6
#  *                    203  0.01s                  1  = L_4
#  ! Time = 0.01s, Average fail depth = 4, Memory usage = 537.0 kB
#  !               Branches  Non-fixed            Branch decision
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 40 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 204
#  ! Number of fails        : 63
#  ! Total memory usage     : 577.8 kB (537.8 kB CP Optimizer + 40.0 kB Concert)
#  ! Time spent in solve    : 0.01s (0.01s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 20400.0
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 7 IS 40 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 8 variables, 3 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 24.0 (before), 24.0 (after)
#  !  . Memory usage      : 267.2 kB (before), 267.2 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     12  0.01s                  3 != L_3
#  *                     14  0.01s                  1  = L_3
#  *                     15  0.01s                  1 != L_3
#  *                     18  0.01s                  1  = L_1
#  *                     20  0.01s                  1  = L_3
#  *                     24  0.01s                  3  = L_1
#  *                     25  0.01s                  3 != L_1
#  *                     40  0.01s                  2  = L_4
#  *                     45  0.01s                  5  = L_7
#  *                     67  0.01s                  4  = L_4
#  *                     70  0.01s                  2 != L_2
#  *                     84  0.01s                  4  = L_3
#  *                     88  0.01s                  3  = L_4
#  *                     94  0.01s                  2 != L_1
#  *                    103  0.01s                  1  = L_2
#  *                    106  0.01s                  2  = L_4
#  *                    113  0.01s                  4 != L_6
#  *                    119  0.01s                  2 != L_7
#  *                    129  0.01s                  2 != L_0
#  *                    136  0.01s                  3  = L_0
#  ! Time = 0.01s, Average fail depth = 4, Memory usage = 537.9 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    151  0.01s                  3  = L_1
#  *                    152  0.01s                  3 != L_1
#  *                    157  0.01s                  4 != L_1
#  *                    165  0.01s                  0  = L_2
#  *                    171  0.01s                  4  = L_3
#  *                    174  0.01s                  0 != L_0
#  *                    178  0.01s                  3  = L_1
#  *                    182  0.01s                  2 != L_3
#  *                    184  0.01s                  0  = L_2
#  *                    185  0.01s                  0 != L_2
#  *                    196  0.01s                  0 != L_4
#  *                    211  0.01s                  1  = L_3
#  *                    226  0.01s                  3  = L_2
#  *                    232  0.01s                  1 != L_0
#  *                    251  0.01s                  2  = L_0
#  *                    270  0.01s                  5  = L_4
#  *                    273  0.01s                  2 != L_2
#  *                    280  0.01s                  0  = L_4
#  *                    282  0.01s                  6 != L_7
#  *                    292  0.01s                  0  = L_0
#  ! Time = 0.01s, Average fail depth = 4, Memory usage = 537.9 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    293  0.01s                  0 != L_0
#  *                    301  0.01s                  1 != L_4
#  *                    319  0.01s                  2 != L_1
#  *                    325  0.01s                  2  = L_3
#  *                    326  0.01s                  2 != L_3
#  *                    330  0.01s                  0  = L_3
#  *                    338  0.01s                  2  = L_0
#  *                    347  0.01s                  3  = L_2
#  *                    361  0.01s                  5  = L_2
#  *                    362  0.01s                  5 != L_2
#  *                    367  0.01s                  1  = L_3
#  *                    371  0.01s                  1  = L_4
#  *                    372  0.01s                  1 != L_4
#  *                    374  0.01s                  0 != L_2
#  *                    380  0.01s                  1 != L_0
#  *                    383  0.01s                  1 != L_6
#  *                    387  0.01s                  2  = L_2
#  *                    397  0.02s                  3 != L_2
#  *                    409  0.02s                  1 != L_7
#  *                    430  0.02s                  1  = L_7
#  ! Time = 0.02s, Average fail depth = 4, Memory usage = 537.9 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    436  0.02s                  0 != L_7
#  *                    466  0.02s                  0  = L_4
#  *                    479  0.02s                  2  = L_7
#  *                    485  0.02s                  0  = L_1
#  *                    486  0.02s                  0 != L_1
#  *                    488  0.02s                  0  = L_3
#  *                    493  0.02s                  4  = L_1
#  *                    494  0.02s                  4 != L_1
#  *                    504  0.02s                  3  = L_3
#  *                    507  0.02s                  0 != L_7
#  *                    510  0.02s                  0  = L_3
#  *                    518  0.02s                  2  = L_0
#  *                    523  0.02s                  1 != L_7
#  *                    537  0.02s                  1  = L_7
#  *                    540  0.02s                  3  = L_3
#  *                    556  0.02s                  2 != L_2
#  *                    562  0.02s                  2  = L_2
#  *                    572  0.02s                  1  = L_1
#  *                    577  0.02s                  3  = L_2
#  *                    578  0.02s                  3 != L_2
#  ! Time = 0.02s, Average fail depth = 4, Memory usage = 537.9 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    582  0.02s                  3  = L_4
#  *                    596  0.02s                  0  = L_7
#  *                    597  0.02s                  0 != L_7
#  *                    601  0.02s                  4  = L_1
#  *                    609  0.02s                  2 != L_6
#  *                    615  0.02s                  4 != L_0
#  *                    620  0.02s                  1 != L_2
#  *                    624  0.02s                  0 != L_1
#  *                    633  0.02s                  1  = L_1
#  *                    638  0.02s                  1 != L_7
#  *                    639  0.02s                  4 != L_0
#  *                    645  0.02s                  0  = L_2
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 92 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 646
#  ! Number of fails        : 232
#  ! Total memory usage     : 578.8 kB (538.7 kB CP Optimizer + 40.0 kB Concert)
#  ! Time spent in solve    : 0.02s (0.02s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 53833.3
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 8 IS 92 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 9 variables, 3 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 28.5 (before), 28.5 (after)
#  !  . Memory usage      : 267.2 kB (before), 267.2 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      5  0.01s                  5  = L_1
#  *                      7  0.01s                  6  = L_1
#  *                     13  0.01s                  6 != L_0
#  *                     23  0.01s                  6  = L_4
#  *                     42  0.01s                  2  = L_0
#  *                     45  0.01s                  2  = L_4
#  *                     46  0.01s                  2 != L_4
#  *                     62  0.01s                  1  = L_8
#  *                     63  0.01s                  1 != L_8
#  *                     72  0.01s                  2  = L_1
#  *                     75  0.01s                  1 != L_3
#  *                     81  0.01s                  1 != L_8
#  *                     87  0.01s                  1 != L_8
#  *                     98  0.01s                  6 != L_2
#  *                    102  0.01s                  1  = L_2
#  *                    109  0.01s                  4  = L_4
#  *                    120  0.01s                  6  = L_4
#  *                    128  0.01s                  7  = L_2
#  *                    129  0.01s                  7 != L_2
#  *                    136  0.01s                  1 != L_8
#  ! Time = 0.01s, Average fail depth = 5, Memory usage = 547.4 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    147  0.01s                  5 != L_3
#  *                    151  0.01s                  3  = L_4
#  *                    169  0.01s                  2  = L_4
#  *                    170  0.01s                  2 != L_4
#  *                    209  0.01s                  6  = L_3
#  *                    223  0.01s                  7 != L_3
#  *                    239  0.01s                  2  = L_6
#  *                    241  0.01s                  1 != L_8
#  *                    245  0.01s                  3  = L_1
#  *                    258  0.01s                  2 != L_2
#  *                    273  0.01s                  5 != L_2
#  *                    279  0.01s                  1  = L_1
#  *                    280  0.01s                  1 != L_1
#  *                    281  0.01s                  5 != L_2
#  *                    283  0.01s                  1  = L_3
#  *                    317  0.01s                  3 != L_6
#  *                    321  0.01s                  2  = L_4
#  *                    324  0.01s                  1 != L_2
#  *                    327  0.01s                  6 != L_2
#  *                    330  0.01s                  3  = L_1
#  ! Time = 0.01s, Average fail depth = 5, Memory usage = 547.4 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    332  0.01s                  6  = L_1
#  *                    349  0.01s                  1  = L_2
#  *                    364  0.01s                  4  = L_0
#  *                    375  0.01s                  3  = L_3
#  *                    412  0.01s                  4  = L_0
#  *                    413  0.01s                  4 != L_0
#  *                    426  0.01s                  0  = L_0
#  *                    431  0.01s                  2 != L_8
#  *                    433  0.01s                  0  = L_0
#  *                    446  0.01s                  0 != L_8
#  *                    458  0.01s                  5  = L_2
#  *                    466  0.01s                  0 != L_3
#  *                    469  0.01s                  3  = L_1
#  *                    471  0.01s                  0 != L_3
#  *                    478  0.01s                  3 != L_0
#  *                    480  0.01s                  0  = L_1
#  *                    481  0.01s                  0 != L_1
#  *                    484  0.01s                  6  = L_3
#  *                    491  0.01s                  6 != L_3
#  *                    492  0.01s                  2 != L_1
#  ! Time = 0.01s, Average fail depth = 5, Memory usage = 547.4 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    513  0.01s                  0 != L_2
#  *                    515  0.01s                  0  = L_3
#  *                    521  0.01s                  0  = L_8
#  *                    535  0.01s                  2  = L_1
#  *                    536  0.01s                  2 != L_1
#  *                    546  0.01s                  0  = L_3
#  *                    547  0.01s                  0 != L_3
#  *                    551  0.01s                  2 != L_7
#  *                    562  0.01s                  2  = L_0
#  *                    569  0.01s                  0  = L_2
#  *                    570  0.01s                  0 != L_2
#  *                    572  0.01s                  5  = L_7
#  *                    574  0.01s                  0  = L_2
#  *                    580  0.01s                  5  = L_8
#  *                    583  0.01s                  2 != L_0
#  *                    587  0.01s                  2  = L_7
#  *                    592  0.01s                  0 != L_3
#  *                    597  0.01s                  4 != L_0
#  *                    604  0.01s                  0  = L_3
#  *                    617  0.01s                  0 != L_1
#  ! Time = 0.01s, Average fail depth = 5, Memory usage = 547.4 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    619  0.01s                  0  = L_2
#  *                    627  0.01s                  2  = L_0
#  *                    628  0.01s                  2 != L_0
#  *                    638  0.01s                  2 != L_2
#  *                    640  0.01s                  0  = L_0
#  *                    643  0.01s                  2  = L_2
#  *                    645  0.01s                  0  = L_7
#  *                    646  0.01s                  0 != L_7
#  *                    667  0.01s                  0  = L_0
#  *                    671  0.01s                  0  = L_1
#  *                    672  0.01s                  0 != L_1
#  *                    675  0.01s                  0 != L_1
#  *                    684  0.01s                  3 != L_8
#  *                    700  0.01s                  1  = L_1
#  *                    701  0.01s                  1 != L_1
#  *                    716  0.01s                  3 != L_3
#  *                    721  0.01s                  3 != L_3
#  *                    725  0.01s                  7  = L_7
#  *                    726  0.01s                  7 != L_7
#  *                    732  0.01s                  1 != L_8
#  ! Time = 0.01s, Average fail depth = 5, Memory usage = 547.4 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    743  0.01s                  4  = L_6
#  *                    744  0.01s                  4 != L_6
#  *                    754  0.01s                  5  = L_7
#  *                    758  0.01s                  6 != L_7
#  *                    766  0.01s                  3  = L_1
#  *                    780  0.01s                  3  = L_2
#  *                    783  0.01s                  1  = L_0
#  *                    792  0.01s                  4  = L_0
#  *                    796  0.01s                  1  = L_2
#  *                    810  0.01s                  4  = L_1
#  *                    814  0.01s                  1 != L_2
#  *                    823  0.02s                  1  = L_8
#  *                    824  0.02s                  1 != L_8
#  *                    833  0.02s                  1  = L_8
#  *                    840  0.02s                  3  = L_3
#  *                    841  0.02s                  3 != L_3
#  *                    843  0.02s                  3  = L_3
#  *                    849  0.02s                  0  = L_8
#  *                    854  0.02s                  0 != L_6
#  *                    861  0.02s                  0  = L_1
#  ! Time = 0.02s, Average fail depth = 5, Memory usage = 547.4 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    866  0.02s                  0  = L_6
#  *                    883  0.02s                  0  = L_8
#  *                    898  0.02s                  3  = L_2
#  *                    906  0.02s                  3  = L_7
#  *                    907  0.02s                  3 != L_7
#  *                    909  0.02s                  0  = L_0
#  *                    910  0.02s                  0 != L_0
#  *                    921  0.02s                  0  = L_1
#  *                    926  0.02s                  0 != L_6
#  *                    929  0.02s                  0 != L_1
#  *                    935  0.02s                  6  = L_6
#  *                    945  0.02s                  2  = L_0
#  *                    948  0.02s                  1  = L_1
#  *                    954  0.02s                  2 != L_0
#  *                    969  0.02s                  6  = L_4
#  *                    974  0.02s                  7  = L_6
#  *                    975  0.02s                  7 != L_6
#  *                    983  0.02s                  4 != L_0
#  *                    989  0.02s                  7 != L_3
#  *                    992  0.02s                  4  = L_1
#  ! Time = 0.02s, Average fail depth = 5, Memory usage = 547.4 kB
#  !               Branches  Non-fixed            Branch decision
#                      1000          2              4  = L_3
#  *                   1005  0.02s                  4 != L_2
#  *                   1013  0.02s                  0 != L_3
#  *                   1020  0.02s                  5 != L_2
#  *                   1028  0.02s                  2  = L_0
#  *                   1029  0.02s                  2 != L_0
#  *                   1031  0.02s                  2  = L_0
#  *                   1032  0.02s                  2 != L_0
#  *                   1037  0.02s                  1  = L_8
#  *                   1039  0.02s                  0  = L_6
#  *                   1052  0.02s                  2 != L_2
#  *                   1059  0.02s                  4  = L_2
#  *                   1065  0.02s                  2  = L_0
#  *                   1066  0.02s                  2 != L_0
#  *                   1071  0.02s                  0 != L_3
#  *                   1081  0.02s                  0 != L_3
#  *                   1085  0.02s                  5 != L_4
#  *                   1087  0.02s                  1  = L_4
#  *                   1103  0.02s                  1  = L_8
#  *                   1106  0.02s                  2 != L_1
#  ! Time = 0.02s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1113  0.02s                  0  = L_1
#  *                   1120  0.02s                  0  = L_3
#  *                   1128  0.02s                  1  = L_8
#  *                   1140  0.02s                  1 != L_8
#  *                   1143  0.02s                  1  = L_6
#  *                   1150  0.02s                  5 != L_0
#  *                   1161  0.02s                  1  = L_2
#  *                   1179  0.02s                  2  = L_8
#  *                   1195  0.02s                  1 != L_3
#  *                   1226  0.03s                  0  = L_4
#  *                   1234  0.03s                  0 != L_4
#  *                   1248  0.03s                  0  = L_6
#  *                   1259  0.03s                  6  = L_8
#  *                   1263  0.03s                  0  = L_6
#  *                   1264  0.03s                  0 != L_6
#  *                   1267  0.03s                  6 != L_8
#  *                   1274  0.03s                  0  = L_3
#  *                   1284  0.03s                  0  = L_8
#  *                   1285  0.03s                  0 != L_8
#  *                   1293  0.03s                  1 != L_6
#  ! Time = 0.03s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1310  0.03s                  1  = L_1
#  *                   1311  0.03s                  1 != L_1
#  *                   1315  0.03s                  2 != L_1
#  *                   1322  0.03s                  6  = L_4
#  *                   1327  0.03s                  6 != L_4
#  *                   1380  0.03s                  1  = L_4
#  *                   1387  0.03s                  1 != L_1
#  *                   1393  0.03s                  3  = L_1
#  *                   1394  0.03s                  3 != L_1
#  *                   1414  0.03s                  1 != L_7
#  *                   1420  0.03s                  1  = L_4
#  *                   1426  0.03s                  4 != L_3
#  *                   1431  0.03s                  6 != L_0
#  *                   1435  0.03s                  2  = L_4
#  *                   1439  0.03s                  0 != L_6
#  *                   1460  0.03s                  1  = L_8
#  *                   1461  0.03s                  1 != L_8
#  *                   1465  0.03s                  4 != L_0
#  *                   1473  0.03s                  4  = L_8
#  *                   1479  0.03s                  2  = L_7
#  ! Time = 0.03s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1480  0.03s                  2 != L_7
#  *                   1481  0.03s                  0 != L_6
#  *                   1487  0.03s                  6  = L_1
#  *                   1495  0.03s                  2  = L_3
#  *                   1507  0.03s                  3 != L_0
#  *                   1512  0.03s                  1 != L_0
#  *                   1515  0.03s                  2  = L_3
#  *                   1516  0.03s                  2 != L_3
#  *                   1526  0.03s                  0 != L_1
#  *                   1528  0.03s                  1  = L_3
#  *                   1529  0.03s                  1 != L_3
#  *                   1540  0.03s                  3  = L_6
#  *                   1546  0.03s                  1 != L_4
#  *                   1563  0.03s                  1  = L_4
#  *                   1575  0.03s                  1  = L_4
#  *                   1585  0.03s                  6  = L_0
#  *                   1592  0.03s                  0  = L_6
#  *                   1596  0.03s                  0  = L_8
#  *                   1601  0.03s                  0 != L_6
#  *                   1606  0.03s                  2  = L_6
#  ! Time = 0.03s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1607  0.03s                  2 != L_6
#  *                   1614  0.03s                  0  = L_7
#  *                   1615  0.03s                  0 != L_7
#  *                   1625  0.03s                  7  = L_8
#  *                   1632  0.03s                  5  = L_3
#  *                   1640  0.03s                  3  = L_6
#  *                   1641  0.03s                  3 != L_6
#  *                   1645  0.03s                  1 != L_3
#  *                   1650  0.03s                  2  = L_3
#  *                   1653  0.03s                  1  = L_3
#  *                   1665  0.03s                  3  = L_4
#  *                   1669  0.03s                  5  = L_8
#  *                   1670  0.03s                  5 != L_8
#  *                   1672  0.03s                  5  = L_2
#  *                   1673  0.03s                  5 != L_2
#  *                   1701  0.03s                  1 != L_2
#  *                   1720  0.03s                  0  = L_4
#  *                   1734  0.03s                  5 != L_8
#  *                   1737  0.03s                  4  = L_1
#  *                   1741  0.03s                  1  = L_3
#  ! Time = 0.03s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1750  0.03s                  0 != L_3
#  *                   1758  0.03s                  4 != L_1
#  *                   1766  0.03s                  1  = L_8
#  *                   1767  0.03s                  1 != L_8
#  *                   1771  0.03s                  0  = L_2
#  *                   1780  0.03s                  2 != L_6
#  *                   1788  0.03s                  1 != L_8
#  *                   1789  0.03s                  0 != L_4
#  *                   1794  0.03s                  2  = L_8
#  *                   1795  0.03s                  2 != L_8
#  *                   1796  0.03s                  1 != L_6
#  *                   1798  0.03s                  7  = L_2
#  *                   1806  0.03s                  2  = L_2
#  *                   1809  0.03s                  1  = L_2
#  *                   1810  0.03s                  1 != L_2
#  *                   1815  0.03s                  4 != L_2
#  *                   1826  0.03s                  0  = L_6
#  *                   1830  0.03s                  2  = L_6
#  *                   1831  0.03s                  2 != L_6
#  *                   1837  0.03s                  1 != L_8
#  ! Time = 0.03s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1842  0.03s                  0 != L_2
#  *                   1854  0.03s                  3  = L_3
#  *                   1858  0.03s                  2  = L_3
#  *                   1859  0.03s                  2 != L_3
#  *                   1862  0.03s                  3 != L_2
#  *                   1887  0.03s                  2  = L_3
#  *                   1891  0.03s                  3  = L_3
#  *                   1893  0.03s                  3  = L_2
#  *                   1894  0.03s                  3 != L_2
#  *                   1899  0.03s                  3  = L_3
#  *                   1904  0.03s                  3  = L_8
#  *                   1905  0.03s                  3 != L_8
#  *                   1912  0.03s                  1  = L_0
#  *                   1917  0.03s                  6 != L_2
#  *                   1927  0.03s                  0 != L_7
#  *                   1929  0.03s                  0  = L_2
#  *                   1931  0.03s                  0  = L_7
#  *                   1932  0.03s                  0 != L_7
#  *                   1941  0.03s                  0  = L_0
#  *                   1942  0.03s                  0 != L_0
#  ! Time = 0.03s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1944  0.03s                  0  = L_8
#  *                   1954  0.03s                  0 != L_7
#  *                   1957  0.03s                  0 != L_0
#  *                   1965  0.03s                  0 != L_8
#  *                   1968  0.03s                  0 != L_2
#  *                   1983  0.03s                  0 != L_8
#  *                   1988  0.03s                  0 != L_1
#  *                   1989  0.03s                  4 != L_3
#                      2000          2        F     3 != L_2
#  *                   2003  0.03s                  4  = L_1
#  *                   2004  0.03s                  4 != L_1
#  *                   2009  0.03s                  5  = L_0
#  *                   2015  0.03s                  6 != L_3
#  *                   2019  0.03s                  6  = L_3
#  *                   2036  0.03s                  6 != L_1
#  *                   2038  0.03s                  3  = L_0
#  *                   2041  0.03s                  1 != L_2
#  *                   2045  0.03s                  2  = L_1
#  *                   2046  0.03s                  2 != L_1
#  *                   2049  0.03s                  0  = L_2
#  ! Time = 0.03s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   2055  0.03s                  1  = L_3
#  *                   2058  0.03s                  0 != L_7
#  *                   2061  0.03s                  2  = L_3
#  *                   2069  0.03s                  0 != L_2
#  *                   2074  0.03s                  1  = L_1
#  *                   2091  0.03s                  6  = L_8
#  *                   2095  0.03s                  0 != L_0
#  *                   2098  0.03s                  0 != L_0
#  *                   2104  0.03s                  1  = L_1
#  *                   2105  0.03s                  1 != L_1
#  *                   2136  0.03s                  1  = L_2
#  *                   2137  0.03s                  1 != L_2
#  *                   2143  0.03s                  2  = L_3
#  *                   2145  0.03s                  1  = L_4
#  *                   2149  0.03s                  1  = L_3
#  *                   2155  0.03s                  1  = L_2
#  *                   2169  0.04s                  5  = L_1
#  *                   2177  0.04s                  5 != L_1
#  *                   2202  0.04s                  0  = L_2
#  *                   2203  0.04s                  0 != L_2
#  ! Time = 0.04s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   2212  0.04s                  2  = L_8
#  *                   2218  0.04s                  3 != L_2
#  *                   2228  0.04s                  3 != L_2
#  *                   2230  0.04s                  2  = L_3
#  *                   2237  0.04s                  0  = L_1
#  *                   2241  0.04s                  0 != L_2
#  *                   2261  0.04s                  3 != L_8
#  *                   2275  0.04s                  1  = L_1
#  *                   2282  0.04s                  0  = L_0
#  *                   2283  0.04s                  0 != L_0
#  *                   2301  0.04s                  2 != L_4
#  *                   2303  0.04s                  6  = L_8
#  *                   2326  0.04s                  1  = L_0
#  *                   2341  0.04s                  3  = L_2
#  *                   2350  0.04s                  2 != L_2
#  *                   2372  0.04s                  3 != L_7
#  *                   2374  0.04s                  1  = L_0
#  *                   2384  0.04s                  1 != L_0
#  *                   2390  0.04s                  2 != L_1
#  *                   2400  0.04s                  6 != L_2
#  ! Time = 0.04s, Average fail depth = 5, Memory usage = 547.8 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   2406  0.04s                  1  = L_7
#  *                   2407  0.04s                  1 != L_7
#  *                   2421  0.04s                  0  = L_2
#  *                   2433  0.04s                  4  = L_8
#  *                   2439  0.04s                  3  = L_1
#  *                   2446  0.04s                  2 != L_7
#  *                   2449  0.04s                  1  = L_8
#  *                   2461  0.04s                  3  = L_1
#  *                   2473  0.04s                  4 != L_0
#  *                   2484  0.04s                  0 != L_7
#  *                   2501  0.04s                  1  = L_3
#  *                   2502  0.04s                  1 != L_3
#  *                   2506  0.04s                  0  = L_4
#  *                   2510  0.04s                  0 != L_1
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 352 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 2510
#  ! Number of fails        : 904
#  ! Total memory usage     : 588.6 kB (548.5 kB CP Optimizer + 40.1 kB Concert)
#  ! Time spent in solve    : 0.04s (0.04s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 78437.5
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 9 IS 352 ****
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 10 variables, 3 constraints
#  ! Presolve             = Off
#  ! Workers              = 1
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.01s propagation)
#  !  . Log search space  : 33.2 (before), 33.2 (after)
#  !  . Memory usage      : 267.3 kB (before), 267.3 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     31  0.01s                  2 != L_4
#  *                     37  0.01s                  3  = L_0
#  *                     38  0.01s                  3 != L_0
#  *                     73  0.01s                  3  = L_4
#  *                     88  0.01s                  7 != L_0
#  *                    114  0.01s                  3 != L_4
#  *                    137  0.01s                  4 != L_8
#  *                    150  0.01s                  2 != L_6
#  *                    160  0.01s                  2  = L_2
#  *                    187  0.01s                  6  = L_8
#  *                    188  0.01s                  6 != L_8
#  *                    212  0.01s                  5 != L_3
#  *                    223  0.01s                  6  = L_2
#  *                    247  0.01s                  1  = L_1
#  *                    257  0.01s                  8  = L_7
#  *                    264  0.01s                  1  = L_7
#  *                    297  0.01s                  5 != L_8
#  *                    312  0.01s                  3 != L_3
#  *                    319  0.01s                  5 != L_8
#  *                    339  0.01s                  7  = L_2
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 548.3 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    348  0.01s                  1 != L_3
#  *                    354  0.01s                  3  = L_1
#  *                    390  0.01s                  5  = L_2
#  *                    396  0.01s                  1  = L_2
#  *                    397  0.01s                  1 != L_2
#  *                    404  0.01s                  1 != L_1
#  *                    408  0.01s                  5  = L_3
#  *                    421  0.01s                  1  = L_8
#  *                    423  0.01s                  1  = L_0
#  *                    424  0.01s                  1 != L_0
#  *                    439  0.01s                  5 != L_3
#  *                    461  0.01s                  4  = L_2
#  *                    484  0.01s                  4  = L_0
#  *                    511  0.01s                  6 != L_4
#  *                    522  0.01s                  1  = L_2
#  *                    561  0.01s                  2 != L_2
#  *                    594  0.01s                  7  = L_4
#  *                    607  0.01s                  4 != L_4
#  *                    617  0.01s                  4  = L_2
#  *                    626  0.01s                  4 != L_7
#  ! Time = 0.01s, Average fail depth = 6, Memory usage = 548.3 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    632  0.01s                  3 != L_1
#  *                    658  0.01s                  4  = L_3
#  *                    681  0.01s                  3  = L_3
#  *                    687  0.01s                  8  = L_2
#  *                    720  0.01s                  1  = L_3
#  *                    725  0.01s                  2  = L_1
#  *                    762  0.02s                  1 != L_3
#  *                    769  0.02s                  7  = L_0
#  *                    778  0.02s                  5  = L_6
#  *                    781  0.02s                  2  = L_4
#  *                    782  0.02s                  2 != L_4
#  *                    785  0.02s                  4  = L_3
#  *                    794  0.02s                  3 != L_1
#  *                    814  0.02s                  8 != L_4
#  *                    842  0.02s                  1 != L_8
#  *                    843  0.02s                  3 != L_3
#  *                    853  0.02s                  2 != L_2
#  *                    854  0.02s                  3 != L_4
#  *                    858  0.02s                  7  = L_1
#  *                    869  0.02s                  3  = L_3
#  ! Time = 0.02s, Average fail depth = 6, Memory usage = 548.3 kB
#  !               Branches  Non-fixed            Branch decision
#  *                    880  0.02s                  8 != L_4
#  *                    900  0.02s                  8 != L_4
#  *                    918  0.02s                  2  = L_2
#  *                    922  0.02s                  5  = L_6
#  *                   1000  0.02s                  6 != L_3
#                      1000          2        F        -
#  *                   1007  0.02s                  6 != L_0
#  *                   1045  0.02s                  5  = L_4
#  *                   1067  0.02s                  6  = L_6
#  *                   1070  0.02s                  6  = L_3
#  *                   1092  0.02s                  6  = L_3
#  *                   1131  0.02s                  6  = L_4
#  *                   1135  0.02s                  3  = L_1
#  *                   1153  0.02s                  5  = L_3
#  *                   1164  0.02s                  2 != L_4
#  *                   1203  0.02s                  2 != L_0
#  *                   1210  0.02s                  2 != L_0
#  *                   1211  0.02s                  1 != L_3
#  *                   1238  0.02s                  7  = L_2
#  *                   1242  0.02s                  2 != L_4
#  ! Time = 0.02s, Average fail depth = 6, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1246  0.02s                  2 != L_4
#  *                   1249  0.02s                  1  = L_3
#  *                   1277  0.02s                  5 != L_4
#  *                   1289  0.02s                  5 != L_1
#  *                   1304  0.02s                  4 != L_3
#  *                   1361  0.02s                  3 != L_1
#  *                   1362  0.02s                  2 != L_4
#  *                   1397  0.02s                  4  = L_7
#  *                   1398  0.02s                  4 != L_7
#  *                   1402  0.02s                  2 != L_4
#  *                   1406  0.02s                  2 != L_1
#  *                   1409  0.02s                  1  = L_7
#  *                   1413  0.02s                  2 != L_6
#  *                   1446  0.02s                  8  = L_7
#  *                   1450  0.02s                  8  = L_0
#  *                   1451  0.02s                  8 != L_0
#  *                   1468  0.02s                  2 != L_8
#  *                   1470  0.02s                  0  = L_8
#  *                   1480  0.02s                  6 != L_9
#  *                   1484  0.02s                  2  = L_2
#  ! Time = 0.02s, Average fail depth = 6, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   1489  0.02s                  6  = L_3
# ...
#  *                   6693  0.06s                  8  = L_2
#  ! Time = 0.06s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   6694  0.06s                  8 != L_2
#  *                   6703  0.06s                  1  = L_4
#  *                   6708  0.06s                  4  = L_1
#  *                   6725  0.06s                  1  = L_0
#  *                   6737  0.06s                  0  = L_1
#  *                   6753  0.06s                  1  = L_1
#  *                   6759  0.06s                  1 != L_3
#  *                   6768  0.06s                  0  = L_1
#  *                   6780  0.06s                  1 != L_1
#  *                   6801  0.06s                  4  = L_0
#  *                   6802  0.06s                  4 != L_0
#  *                   6822  0.06s                  4 != L_0
#  *                   6918  0.06s                  6 != L_0
#  *                   6970  0.06s                  5 != L_0
#  *                   6995  0.06s                  0  = L_9
#  *                   7000  0.06s                  0 != L_8
#                      7000          2        F        -
#  *                   7011  0.06s                  2  = L_8
#  *                   7019  0.06s                  5  = L_9
#  *                   7020  0.06s                  5 != L_9
#  ! Time = 0.06s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   7046  0.06s                  2  = L_8
#  *                   7047  0.06s                  2 != L_8
#  *                   7057  0.06s                  1 != L_9
#  *                   7067  0.06s                  4 != L_1
#  *                   7073  0.06s                  1  = L_1
#  *                   7096  0.06s                  0  = L_9
#  *                   7098  0.06s                  5 != L_0
#  *                   7114  0.06s                  8  = L_2
#  *                   7119  0.06s                  2 != L_6
#  *                   7145  0.06s                  3 != L_8
#  *                   7149  0.06s                  0  = L_9
#  *                   7156  0.06s                  0 != L_8
#  *                   7163  0.06s                  1  = L_6
#  *                   7164  0.06s                  1 != L_6
#  *                   7196  0.07s                  0 != L_2
#  *                   7210  0.07s                  1 != L_9
#  *                   7226  0.07s                  6  = L_2
#  *                   7229  0.07s                  0 != L_6
#  *                   7236  0.07s                  2  = L_8
#  *                   7243  0.07s                  2 != L_9
#  ! Time = 0.07s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   7258  0.07s                  1  = L_9
#  *                   7259  0.07s                  1 != L_9
#  *                   7264  0.07s                  0 != L_2
#  *                   7268  0.07s                  0  = L_9
#  *                   7278  0.07s                  1 != L_9
#  *                   7279  0.07s                  4 != L_1
#  *                   7283  0.07s                  2  = L_6
#  *                   7288  0.07s                  2 != L_8
#  *                   7289  0.07s                  0 != L_1
#  *                   7290  0.07s                  1 != L_4
#  *                   7354  0.07s                  4  = L_3
#  *                   7370  0.07s                  7  = L_3
#  *                   7383  0.07s                  5 != L_7
#  *                   7404  0.07s                  2 != L_9
#  *                   7409  0.07s                  1  = L_0
#  *                   7410  0.07s                  1 != L_0
#  *                   7413  0.07s                  3  = L_3
#  *                   7418  0.07s                  3  = L_9
#  *                   7426  0.07s                  1  = L_8
#  *                   7427  0.07s                  1 != L_8
#  ! Time = 0.07s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   7436  0.07s                  6 != L_2
#  *                   7444  0.07s                  3  = L_9
#  *                   7514  0.07s                  5  = L_3
#  *                   7525  0.07s                  2 != L_2
#  *                   7538  0.07s                  4 != L_2
#  *                   7544  0.07s                  0 != L_7
#  *                   7547  0.07s                  3  = L_3
#  *                   7551  0.07s                  0 != L_2
#  *                   7564  0.07s                  2  = L_1
#  *                   7567  0.07s                  2  = L_7
#  *                   7573  0.07s                  2 != L_2
#  *                   7578  0.07s                  2  = L_1
#  *                   7579  0.07s                  2 != L_1
#  *                   7592  0.07s                  0  = L_0
#  *                   7605  0.07s                  4  = L_2
#  *                   7609  0.07s                  3  = L_3
#  *                   7625  0.07s                  0 != L_8
#  *                   7627  0.07s                  2  = L_7
#  *                   7632  0.07s                  2  = L_0
#  *                   7633  0.07s                  2 != L_0
#  ! Time = 0.07s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   7649  0.07s                  0 != L_7
#  *                   7653  0.07s                  0  = L_8
#  *                   7654  0.07s                  0 != L_8
#  *                   7655  0.07s                  2 != L_0
#  *                   7662  0.07s                  7  = L_8
#  *                   7663  0.07s                  7 != L_8
#  *                   7666  0.07s                  2 != L_0
#  *                   7671  0.07s                  0  = L_1
#  *                   7678  0.07s                  3 != L_9
#  *                   7683  0.07s                  5  = L_0
#  *                   7690  0.07s                  0  = L_1
#  *                   7739  0.07s                  7  = L_7
#  *                   7743  0.07s                  1  = L_1
#  *                   7756  0.07s                  1  = L_9
#  *                   7762  0.07s                  4 != L_3
#  *                   7769  0.07s                  3  = L_8
#  *                   7770  0.07s                  3 != L_8
#  *                   7773  0.07s                  5 != L_3
#  *                   7788  0.07s                  3  = L_2
#  *                   7789  0.07s                  3 != L_2
#  ! Time = 0.07s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   7791  0.07s                  1 != L_7
#  *                   7797  0.07s                  1  = L_2
#  *                   7810  0.07s                  2 != L_1
#  *                   7812  0.07s                  1 != L_3
#  *                   7825  0.07s                  2  = L_1
#  *                   7826  0.07s                  2 != L_1
#  *                   7830  0.07s                  1 != L_1
#  *                   7835  0.07s                  1 != L_8
#  *                   7843  0.07s                  4  = L_7
#  *                   7877  0.07s                  7  = L_1
#  *                   7894  0.07s                  2  = L_0
#  *                   7914  0.07s                  6 != L_8
#  *                   7935  0.07s                  2 != L_7
#  *                   7962  0.07s                  3  = L_2
#  *                   7963  0.07s                  3 != L_2
#  *                   7980  0.07s                  1  = L_3
#  *                   7998  0.07s                  2 != L_7
#                      8000          2        F     2  = L_7
#  *                   8001  0.07s                  2 != L_7
#  *                   8011  0.07s                  2  = L_8
#  ! Time = 0.07s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   8061  0.07s                  2  = L_8
#  *                   8080  0.07s                  0  = L_2
#  *                   8091  0.07s                  0  = L_2
#  *                   8119  0.07s                  0  = L_2
#  *                   8139  0.07s                  1 != L_2
#  *                   8155  0.07s                  0 != L_3
#  *                   8172  0.07s                  7  = L_8
#  *                   8201  0.07s                  2  = L_3
#  *                   8213  0.07s                  2 != L_3
#  *                   8218  0.07s                  7  = L_8
#  *                   8220  0.08s                  0  = L_1
#  *                   8229  0.08s                  0 != L_1
#  *                   8241  0.08s                  5 != L_7
#  *                   8264  0.08s                  3 != L_2
#  *                   8267  0.08s                  0 != L_9
#  *                   8291  0.08s                  0 != L_1
#  *                   8295  0.08s                  4  = L_8
#  *                   8298  0.08s                  4  = L_8
#  *                   8302  0.08s                  2  = L_3
#  *                   8308  0.08s                  0 != L_7
#  ! Time = 0.08s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   8337  0.08s                  5  = L_6
#  *                   8382  0.08s                  4  = L_4
#  *                   8401  0.08s                  2 != L_6
#  *                   8411  0.08s                  1  = L_0
#  *                   8426  0.08s                  1  = L_1
#  *                   8444  0.08s                  1  = L_7
#  *                   8445  0.08s                  1 != L_7
#  *                   8449  0.08s                  3 != L_1
#  *                   8485  0.08s                  2 != L_0
#  *                   8519  0.08s                  2 != L_7
#  *                   8526  0.08s                  0  = L_7
#  *                   8534  0.08s                  2  = L_6
#  *                   8547  0.08s                  3 != L_6
#  *                   8556  0.08s                  2 != L_8
#  *                   8574  0.08s                  2  = L_6
#  *                   8576  0.08s                  3  = L_6
#  *                   8603  0.08s                  0 != L_1
#  *                   8629  0.08s                  4  = L_7
#  *                   8676  0.08s                  6 != L_9
#  *                   8680  0.08s                  3  = L_8
#  ! Time = 0.08s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   8683  0.08s                  3 != L_6
#  *                   8685  0.08s                  1  = L_6
#  *                   8690  0.08s                  3 != L_0
#  *                   8696  0.08s                  1 != L_6
#  *                   8735  0.08s                  0 != L_6
#  *                   8749  0.08s                  0 != L_7
#  *                   8771  0.08s                  0  = L_8
#  *                   8786  0.08s                  2 != L_9
#  *                   8808  0.08s                  6  = L_9
#  *                   8812  0.08s                  4 != L_7
#  *                   8855  0.08s                  0 != L_1
#  *                   8861  0.08s                  1  = L_6
#  *                   8862  0.08s                  1 != L_6
#  *                   8876  0.08s                  2  = L_6
#  *                   8887  0.08s                  2 != L_9
#  *                   8900  0.08s                  0 != L_1
#  *                   8906  0.08s                  0  = L_9
#  *                   8969  0.08s                  5 != L_6
#  *                   8974  0.08s                  1 != L_8
#  *                   8979  0.08s                  0  = L_0
#  ! Time = 0.08s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   8980  0.08s                  0 != L_0
#  *                   8982  0.08s                  0  = L_2
#  *                   8988  0.08s                  5 != L_0
#                      9000          2        F     3  = L_6
#  *                   9007  0.08s                  5  = L_7
#  *                   9037  0.08s                  0 != L_6
#  *                   9054  0.08s                  1  = L_2
#  *                   9070  0.08s                  2 != L_7
#  *                   9081  0.08s                  7  = L_2
#  *                   9118  0.08s                  2 != L_9
#  *                   9122  0.08s                  0  = L_2
#  *                   9123  0.08s                  0 != L_2
#  *                   9126  0.08s                  2 != L_8
#  *                   9133  0.08s                  2 != L_8
#  *                   9144  0.08s                  1 != L_8
#  *                   9150  0.08s                  2  = L_7
#  *                   9151  0.08s                  2 != L_7
#  *                   9156  0.08s                  1 != L_1
#  *                   9158  0.08s                  4  = L_7
#  *                   9167  0.08s                  0 != L_1
#  ! Time = 0.08s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   9170  0.08s                  3  = L_8
#  *                   9171  0.08s                  3 != L_8
#  *                   9184  0.08s                  2  = L_7
#  *                   9201  0.08s                  2 != L_8
#  *                   9203  0.08s                  1  = L_8
#  *                   9241  0.08s                  1 != L_8
#  *                   9272  0.08s                  0  = L_8
#  *                   9298  0.08s                  1  = L_4
#  *                   9310  0.08s                  1  = L_6
#  *                   9328  0.08s                  2 != L_6
#  *                   9336  0.09s                  0  = L_6
#  *                   9343  0.09s                  1 != L_4
#  *                   9347  0.09s                  0  = L_0
#  *                   9357  0.09s                  1  = L_9
#  *                   9371  0.09s                  3 != L_8
#  *                   9411  0.09s                  4  = L_9
#  *                   9412  0.09s                  4 != L_9
#  *                   9418  0.09s                  1 != L_4
#  *                   9420  0.09s                  3  = L_6
#  *                   9458  0.09s                  1 != L_7
#  ! Time = 0.09s, Average fail depth = 5, Memory usage = 548.7 kB
#  !               Branches  Non-fixed            Branch decision
#  *                   9462  0.09s                  0 != L_4
#  *                   9472  0.09s                  0  = L_4
#  *                   9488  0.09s                  5  = L_7
#  *                   9489  0.09s                  5 != L_7
#  *                   9499  0.09s                  1  = L_1
#  *                   9501  0.09s                  1  = L_6
#  *                   9502  0.09s                  1 != L_6
#  *                   9519  0.09s                  0 != L_2
#  *                   9533  0.09s                  1 != L_2
#  *                   9547  0.09s                  0  = L_4
#  *                   9551  0.09s                  2  = L_8
#  *                   9585  0.09s                  2 != L_7
#  *                   9606  0.09s                  2 != L_7
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 724 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 9624
#  ! Number of fails        : 4089
#  ! Total memory usage     : 589.6 kB (549.4 kB CP Optimizer + 40.2 kB Concert)
#  ! Time spent in solve    : 0.09s (0.09s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 117365.9
#  ! ----------------------------------------------------------------------------
#          **** THE NUMBER OF SOLUTIONS FOR N = 10 IS 724 ****

# %% [markdown]
# ## 2. Comparison of the two models

# %% [markdown]
# We will compare the two models properly.
#
# **Exercice:** Consider the `run(model, params)` function that we used in the first tutorial and paste it here.

# %%
from docplex.cp.parameters import CpoParameters

def run(model,params):
    sol = model.solve(TimeLimit= params.TimeLimit , LogVerbosity = params.LogVerbosity )

    search_status = sol.get_solver_infos()['SearchStatus']
    number_of_nodes = 1 + sol.get_solver_infos()['NumberOfBranches']
    total_runtime = sol.get_solver_infos()['TotalTime']
    return [number_of_nodes,total_runtime,search_status]

# %% [markdown]
# ### 2.1. Basic comparison
#
# To compare the two models, we will fix the time limit to 5 seconds, i.e. `TimeLimit=5`, while keeping all the other parameters to their default values.

# %% [markdown]
# **Exercice:** Compare the two models for $N \in \{200, 400, 600, .., 2000 \}$.
#
# <div class="alert alert-block alert-info">
#
# By *comparing* we mean plotting the runtime **and** the number of decisions made by the solver for each model as a function of $n$
#
# </div>

# %%
test=[i*200 for i in range(1,11)]

params = CpoParameters(TimeLimit=5)

Y_decomp_time = []
Y_decomp_nodes = []
Y_alldiff_time = []
Y_alldiff_nodes = []
for n in test:
    L_n=run(decomposition_model(n),params)
    Y_decomp_nodes.append(L_n[0])
    Y_decomp_time.append(L_n[1])
    L_n_diff=run(global_constraint_model(n),params)
    Y_alldiff_nodes.append(L_n_diff[0])
    Y_alldiff_time.append(L_n_diff[1])
    print(L_n, " ", L_n_diff)
# Out:
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 200 variables, 19901 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.05s (0.05s extraction + 0.00s propagation)
#  !  . Log search space  : 1528.8 (before), 1528.8 (after)
#  !  . Memory usage      : 6.6 MB (before), 6.6 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000         21        F    44  = L_188
#                      2000         12            161  = L_155
#                      3000         12             91  = L_163
#  *                   3157  0.20s                172  = L_149
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 3157
#  ! Number of fails        : 1216
#  ! Total memory usage     : 94.7 MB (94.6 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.20s (0.15s engine + 0.05s extraction)
#  ! Search speed (br. / s) : 22076.9
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 200 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 1528.8 (before), 1528.8 (after)
#  !  . Memory usage      : 398.7 kB (before), 398.7 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                    197  0.01s                107  = L_192
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 197
#  ! Number of fails        : 2
#  ! Total memory usage     : 2.4 MB (2.4 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.01s (0.01s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 19700.0
#  ! ----------------------------------------------------------------------------
# [3158, 0.191, 'SearchCompleted']   [198, 0.006, 'SearchCompleted']
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 400 variables, 79801 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.25s (0.25s extraction + 0.01s propagation)
#  !  . Log search space  : 3457.5 (before), 3457.5 (after)
#  !  . Memory usage      : 25.4 MB (before), 25.4 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000         86        F   356  = L_222
#                      2000         29        F   396  = L_92
#                      3000         14            113  = L_150
#                      4000         61        F   182  = L_164
#                      5000         19        F   143  = L_336
#  *                   5945  0.92s                369 != L_373
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 5945
#  ! Number of fails        : 2455
#  ! Total memory usage     : 232.6 MB (232.5 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.92s (0.67s engine + 0.25s extraction)
#  ! Search speed (br. / s) : 8953.3
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 400 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 3457.5 (before), 3457.5 (after)
#  !  . Memory usage      : 522.4 kB (before), 522.4 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                    395  0.02s                312  = L_7
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 395
#  ! Number of fails        : 1
#  ! Total memory usage     : 5.7 MB (5.6 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.02s (0.02s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 35909.1
#  ! ----------------------------------------------------------------------------
# [5946, 0.913, 'SearchCompleted']   [396, 0.013, 'SearchCompleted']
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 600 variables, 179701 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.58s (0.58s extraction + 0.01s propagation)
#  !  . Log search space  : 5537.3 (before), 5537.3 (after)
#  !  . Memory usage      : 56.8 MB (before), 56.8 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000        207            141  = L_389
#                      2000         85            240 != L_320
#                      3000         33        F   396  = L_195
#                      4000         24             87 != L_46
#                      5000        107        F   370  = L_491
#                      6000         38            279 != L_376
#                      7000         19        F   405  = L_470
#                      8000        141        F    92  = L_241
#                      9000         42             94 != L_4
#                     10000         21            476  = L_75
#  ! ----------------------------------------------------------------------------
#  ! Search terminated by limit, no solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 10390
#  ! Number of fails        : 4089
#  ! Total memory usage     : 1.6 GB (1.6 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 5.49s (4.92s engine + 0.58s extraction)
#  ! Search speed (br. / s) : 2115.7
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 600 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 5537.3 (before), 5537.3 (after)
#  !  . Memory usage      : 654.3 kB (before), 654.3 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                    598  0.03s                  9  = L_40
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 598
#  ! Number of fails        : 0
#  ! Total memory usage     : 10.5 MB (10.4 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.03s (0.03s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 23000.0
#  ! ----------------------------------------------------------------------------
# [10391, 5.486, 'SearchStopped']   [599, 0.029, 'SearchCompleted']
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 800 variables, 319601 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 1.00s (1.00s extraction + 0.01s propagation)
#  !  . Log search space  : 7715.1 (before), 7715.1 (after)
#  !  . Memory usage      : 100.7 MB (before), 100.7 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000        341            594 != L_469
#                      2000        173            186 != L_124
#                      3000         84        F   675  = L_552
#                      4000         51        F   776  = L_219
#                      5000        309             56 != L_537
#                      6000        170        F   715  = L_43
#                      7000         79            658 != L_536
#                      8000         38            300 != L_330
#                      9000         41            253  = L_472
#                     10000        189            478 != L_354
#                     11000         79            325 != L_310
#                     12000         27            340 != L_215
#  ! ----------------------------------------------------------------------------
#  ! Search terminated by limit, no solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 12177
#  ! Number of fails        : 4919
#  ! Total memory usage     : 1.7 GB (1.7 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 5.56s (4.56s engine + 1.00s extraction)
#  ! Search speed (br. / s) : 2670.4
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 800 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 7715.1 (before), 7715.1 (after)
#  !  . Memory usage      : 810.0 kB (before), 810.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000          6            794  = L_119
#  *                   1604  0.10s                109  = L_753
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 1604
#  ! Number of fails        : 107
#  ! Total memory usage     : 22.1 MB (22.0 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.10s (0.10s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 16884.2
#  ! ----------------------------------------------------------------------------
# [12178, 5.555, 'SearchStopped']   [1605, 0.099, 'SearchCompleted']
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 1000 variables, 499501 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 1.72s (1.71s extraction + 0.02s propagation)
#  !  . Log search space  : 9965.8 (before), 9965.8 (after)
#  !  . Memory usage      : 157.1 MB (before), 157.1 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000        484        F   583  = L_334
#                      2000        285             35 != L_252
#                      3000        180        F   227  = L_658
#                      4000         93            892 != L_674
#                      5000         48            195 != L_218
#                      6000         35        F   431  = L_682
#                      7000         36        F   319  = L_459
#                      8000         53            398 != L_631
#  ! ----------------------------------------------------------------------------
#  ! Search terminated by limit, no solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 8941
#  ! Number of fails        : 3758
#  ! Total memory usage     : 1.5 GB (1.5 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 5.42s (3.72s engine + 1.71s extraction)
#  ! Search speed (br. / s) : 2406.1
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 1000 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 9965.8 (before), 9965.8 (after)
#  !  . Memory usage      : 933.7 kB (before), 933.7 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000         10        F   560  = L_0
#                      2000          5            966  = L_991
#  *                   2088  0.15s                745  = L_991
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 2088
#  ! Number of fails        : 239
#  ! Total memory usage     : 34.1 MB (34.0 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.15s (0.15s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 14914.3
#  ! ----------------------------------------------------------------------------
# [8942, 5.418, 'SearchStopped']   [2089, 0.144, 'SearchCompleted']
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 1200 variables, 719401 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 2.40s (2.39s extraction + 0.02s propagation)
#  !  . Log search space  : 12274.6 (before), 12274.6 (after)
#  !  . Memory usage      : 226.1 MB (before), 226.1 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000        667            450 != L_638
#                      2000        407            771 != L_303
#                      3000        266        F   752  = L_362
#                      4000        167            431 != L_917
#                      5000        102        F   955  = L_643
#                      6000         50        F   428  = L_776
#  ! ----------------------------------------------------------------------------
#  ! Search terminated by limit, no solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 6136
#  ! Number of fails        : 2494
#  ! Total memory usage     : 1.5 GB (1.5 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 5.11s (2.73s engine + 2.39s extraction)
#  ! Search speed (br. / s) : 2250.1
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 1200 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 12274.6 (before), 12274.6 (after)
#  !  . Memory usage      : 1.1 MB (before), 1.1 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000        201            766  = L_149
#  *                   1196  0.12s               1139  = L_1158
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 1196
#  ! Number of fails        : 0
#  ! Total memory usage     : 33.5 MB (33.4 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.12s (0.12s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 10491.2
#  ! ----------------------------------------------------------------------------
# [6137, 5.108, 'SearchStopped']   [1197, 0.119, 'SearchCompleted']
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 1400 variables, 979301 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 3.17s (3.15s extraction + 0.02s propagation)
#  !  . Log search space  : 14631.7 (before), 14631.7 (after)
#  !  . Memory usage      : 307.6 MB (before), 307.6 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000        825            896 != L_1253
#                      2000        554        F   890  = L_899
#                      3000        366        F   864  = L_724
#                      4000        233            957 != L_342
#                      5000        153            330 != L_325
#                      6000         94        F   151  = L_1016
#  ! ----------------------------------------------------------------------------
#  ! Search terminated by limit, no solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 6898
#  ! Number of fails        : 2776
#  ! Total memory usage     : 2.0 GB (2.0 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 5.23s (2.09s engine + 3.15s extraction)
#  ! Search speed (br. / s) : 3314.8
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 1400 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 14631.7 (before), 14631.7 (after)
#  !  . Memory usage      : 1.2 MB (before), 1.2 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000        401            550  = L_1170
#  *                   1398  0.19s               1111  = L_90
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 1398
#  ! Number of fails        : 0
#  ! Total memory usage     : 44.0 MB (43.9 MB CP Optimizer + 0.2 MB Concert)
#  ! Time spent in solve    : 0.19s (0.19s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 7639.3
#  ! ----------------------------------------------------------------------------
# [6899, 5.227, 'SearchStopped']   [1399, 0.19, 'SearchCompleted']
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 1600 variables, 1279201 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 4.16s (4.14s extraction + 0.02s propagation)
#  !  . Log search space  : 17030.2 (before), 17030.2 (after)
#  !  . Memory usage      : 401.5 MB (before), 401.5 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000       1005           1140 != L_107
#  ! ----------------------------------------------------------------------------
#  ! Search terminated by limit, no solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 1935
#  ! Number of fails        : 514
#  ! Total memory usage     : 2.2 GB (2.2 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 5.18s (1.04s engine + 4.14s extraction)
#  ! Search speed (br. / s) : 1860.6
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 1600 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 17030.2 (before), 17030.2 (after)
#  !  . Memory usage      : 1.4 MB (before), 1.4 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000        601              3  = L_1201
#  *                   1593  0.21s               1388  = L_96
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 1593
#  ! Number of fails        : 0
#  ! Total memory usage     : 55.9 MB (55.8 MB CP Optimizer + 0.2 MB Concert)
#  ! Time spent in solve    : 0.21s (0.21s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 7925.4
#  ! ----------------------------------------------------------------------------
# [1936, 5.175, 'SearchStopped']   [1594, 0.208, 'SearchCompleted']
#  ! ----------------------------------------------------------------------------
#  ! Problem could not be loaded within the time limit
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! ----------------------------------------------------------------------------
#  ! Total memory usage     : 2.5 GB (2.5 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 5.19s (0.04s engine + 5.15s extraction)
#  ! ----------------------------------------------------------------------------
#  ! ----------------------------------------------------------------------------
#  ! Search terminated by limit, no solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 0
#  ! Number of fails        : 0
#  ! Total memory usage     : 2.5 GB (2.5 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 5.22s (0.07s engine + 5.15s extraction)
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 1800 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 19464.8 (before), 19464.8 (after)
#  !  . Memory usage      : 1.4 MB (before), 1.4 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000        801           1301  = L_1344
#  *                   1797  0.26s                 97  = L_1618
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 1797
#  ! Number of fails        : 0
#  ! Total memory usage     : 69.3 MB (69.1 MB CP Optimizer + 0.2 MB Concert)
#  ! Time spent in solve    : 0.26s (0.25s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 7275.3
#  ! ----------------------------------------------------------------------------
# [1, 5.215, 'SearchStopped']   [1798, 0.255, 'SearchCompleted']
#  ! ----------------------------------------------------------------------------
#  ! Problem could not be loaded within the time limit
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! ----------------------------------------------------------------------------
#  ! Total memory usage     : 2.9 GB (2.9 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 6.36s (0.04s engine + 6.33s extraction)
#  ! ----------------------------------------------------------------------------
#  ! ----------------------------------------------------------------------------
#  ! Search terminated by limit, no solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 0
#  ! Number of fails        : 0
#  ! Total memory usage     : 2.9 GB (2.9 GB CP Optimizer + 0.0 GB Concert)
#  ! Time spent in solve    : 6.41s (0.08s engine + 6.33s extraction)
#  ! ----------------------------------------------------------------------------
#  ! --------------------------------------------------- CP Optimizer 22.1.1.0 --
#  ! Satisfiability problem - 2000 variables, 3 constraints
#  ! Presolve             = Off
#  ! TimeLimit            = 5
#  ! Workers              = 1
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 21931.6 (before), 21931.6 (after)
#  !  . Memory usage      : 1.7 MB (before), 1.7 MB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000       1001           1710  = L_980
#  *                   1995  0.32s               1868  = L_1932
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 1995
#  ! Number of fails        : 0
#  ! Total memory usage     : 85.5 MB (85.3 MB CP Optimizer + 0.2 MB Concert)
#  ! Time spent in solve    : 0.32s (0.31s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 6477.3
#  ! ----------------------------------------------------------------------------
# [1, 6.404, 'SearchStopped']   [1996, 0.317, 'SearchCompleted']

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(200,2000,10)


plt.figure(figsize=(12, 12))

plt.subplot(2,1,1)
plt.scatter(x,Y_decomp_time,lw=2,ls="--")
plt.scatter(x,Y_alldiff_time,lw=2,ls="--")

plt.title('figure 1')
plt.xlabel('n')
plt.ylabel('runtime')


plt.subplot(2,1,2)
plt.scatter(x,Y_decomp_nodes,lw=2,ls="--")
plt.scatter(x,Y_alldiff_nodes,lw=2,ls="--")

plt.title('figure 2')
plt.xlabel('n')
plt.ylabel('nodes')
plt.show()
# %matplotlib inline

# %% [markdown]
# **Question:** What do you observe? Why?

# %% [raw]
# As n gets larger, the non global constraint algorithm explores no more than 1 node; the search does not even begin because the modeling part took more than 5 seconds to set the constraints. On the other hand, all_diff option allows us to use much less memory and provides the search algorithm more time to run.

# %% [markdown]
# ### 2.2. Branching strategies
#
#
# **Important:** Before you start this part, please ask one of your supervisors to check on your work.
#
# A CP solver is, at the end of the day, a backtracking solver. At each node, it applies filtering (called also propagation or pruning), then make a decision about the next node to explore. This decision is a pure heuristic choice, that is, it could be a wrong decision, it is only based on intuition.
#
# In CP, a decision is, most of the times, of the type: choose an unassigned variable $x$, choose a value $v$ from the current domain of $x$, and assign $v$ to $x$. These steps require a variable heuristic and a value heuristic. This is what we call branching strategy.
#
# Branching strategies can be generic (strategies that can be used for any problem), or specific (designed for the problem at hand). In CPOptimizer, there are a number of genereic strategies offered. This concerns both variable and value heuristics.
#
# For example, if $L$ is the list of decision variables, then by declaring a search_phase as follows:
#
# ```python
# SearchPhase= model.search_phase(L,
#                                 varchooser=model.select_smallest(model.domain_size()),
#                                 valuechooser=model.select_random_value())
#
# model.add_search_phase(SearchPhase)
# ```
#
# The variable heuristic here is the one that picks the variable $x$ with the smallest domain size, and assigns a random value from its domain to it.
#
#
# Read about the different search strategies here:
# http://ibmdecisionoptimization.github.io/docplex-doc/cp/docplex.cp.modeler.py.html#search-phases
#
#
# We want to evaluate different strategies:
# - For variable evaluators, we will use
#  - `domain_size()`
#  - `var_impact()`
#  - `var_local_impact()`
#  - `var_index()`
#
# - For value evaluators, we will use
#  - `value_impact()`
#  - `value_index()`
#
# As for the selectors we will use :
# - `select_smallest()`
# - `select_largest()`
#
# **Question:** How many strategies are we going to evaluate?

# %% [raw]
# 16

# %% [markdown]
# **Question:** In addition to the above strategies, we will use also a pure random selection for variables and values. How can we use such a branching heuristic?

# %% [raw]
# We

# %% [markdown]
# Using the global constraints model, run the different strategies (**all of them, and pure random**) for different values of $N$. Make sure you choose a good value of $N$ that can assess your claims of evaluation. Feel free to use any reasnable time limit.
#
# <div class="alert alert-block alert-danger">
#
# **Important:** For this exercice, you must set the `SearchType` to `DepthFirst` using `SearchType="DepthFirst"` when calling `run`.
#
# We will investigate deeply this choice in the next tutorial. But at this stage you should trust us and include it in the solver's parameters.
#
# </div>
#
# **Exercice:** Present the results (rutime + number of nodes) via a table first then using plots.

# %% [markdown]
# # Plots

# %% [markdown]
# # Compare value chooser

# %% [markdown]
# ## var chooser = select smallest

# %% [markdown]
# ## varchooser = select largest

# %% [markdown]
# # Compare var chooser

# %% [markdown]
# ## Value chooser = smallest value impact

# %% [markdown]
# ## Value chooser = smallest value index

# %% [markdown]
# ## Value chooser = largest value impact

# %% [markdown]
# ## Value chooser = larget value index

# %% [markdown]
# ## Random select

# %% [markdown]
# **Question:** Is this what you expect? Is the choice of the branching strategy important? Justify.

# %% [markdown]
# On attendait plus de variations et moins de timeout : presque toutes les stratégies ont un timeout après n=50

# %% [markdown]
# **Question:** What is more important, the variable ordering or the value ordering choice? Justify.

# %% [markdown]
# Pour un value chooser donné, le choix du var chooser impacte plus les résultats. Alors que sur les plots on remarque que pour un var chooser donné, le value chooser ne change rien aux résultats.

# %% [markdown]
# **Question:** What is the best variable ordering choice? Justify.

# %% [markdown]
# Le meilleur semble être le smallest domain size : il a le moins de timeout, le moins de noeuds, et le plus de solutions feasible (les autres ont trop de unknown)

# %% [markdown]
# **Question:** What is the best value ordering choice? Justify.

# %% [markdown]
# Pas de différences observées

# %% [markdown]
# **Question:** What is a good branching overall? Any thoughts why this is the case? Justify.

# %% [markdown]
# Le random est étonnement plutôt bon dans notre cas

# %% [markdown]
# **Question:** Did you observe an opposite behaviour of heuristics betwen the runtime and the number of nodes?
# For instance, is there a strategy that is faster than others to solve the problem but requires a larger number of nodes?
# And conversely, is there a heuristic that is slow to solve the problem than others but uses less nodes?
# If you observe this, why is this happening?

# %% [markdown]
# ## 3. Conclusion
#
# **Question:** What did you learn today?

# %% [markdown]
# <div class="alert alert-block alert-danger"></div>
